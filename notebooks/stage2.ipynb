# %% [markdown]
# # SETUP

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Tue_Mar__8_18:18:20_PST_2022
# Cuda compilation tools, release 11.6, V11.6.124
# Build cuda_11.6.r11.6/compiler.31057947_0
# Sun Feb 12 09:46:44 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.65.01    Driver Version: 515.65.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:90:00.0 Off |                    0 |
# | N/A   37C    P0    61W / 400W |      0MiB / 81920MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !python -m pip install paddlepaddle-gpu==2.4.1.post117 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# Looking in links: https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# Requirement already satisfied: paddlepaddle-gpu==2.4.1.post117 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (2.4.1.post117)
# Requirement already satisfied: numpy>=1.13 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from paddlepaddle-gpu==2.4.1.post117) (1.22.4)
# Requirement already satisfied: paddle-bfloat==0.1.7 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from paddlepaddle-gpu==2.4.1.post117) (0.1.7)
# Requirement already satisfied: opt-einsum==3.3.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from paddlepaddle-gpu==2.4.1.post117) (3.3.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from paddlepaddle-gpu==2.4.1.post117) (9.2.0)
# Collecting protobuf<=3.20.0,>=3.1.0
#   Downloading protobuf-3.20.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.7 MB/s eta 0:00:00:00:010:01
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.8/dist-packages (from paddlepaddle-gpu==2.4.1.post117) (2.28.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from paddlepaddle-gpu==2.4.1.post117) (1.15.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from paddlepaddle-gpu==2.4.1.post117) (5.1.1)
# Requirement already satisfied: astor in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from paddlepaddle-gpu==2.4.1.post117) (0.8.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20.0->paddlepaddle-gpu==2.4.1.post117) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20.0->paddlepaddle-gpu==2.4.1.post117) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20.0->paddlepaddle-gpu==2.4.1.post117) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20.0->paddlepaddle-gpu==2.4.1.post117) (2022.9.24)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# Installing collected packages: protobuf
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# visualdl 2.5.0 requires flask>=1.1.1, which is not installed.
# tensorboard 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.0 which is incompatible.
# cudf 22.8.0a0+304.g6ca81bbc78.dirty requires protobuf<3.21.0a0,>=3.20.1, but you have protobuf 3.20.0 which is incompatible.
# Successfully installed protobuf-3.20.0

# %%
# %%bash
# cd PaddleDetection
# pip install -r requirements.txt
# python setup.py install
# cd ../
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 1)) (4.64.1)
# Requirement already satisfied: typeguard in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (2.13.3)
# Requirement already satisfied: visualdl>=2.2.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (2.5.0)
# Collecting opencv-python<=4.6.0
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 41.6 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 5)) (6.0)
# Requirement already satisfied: shapely in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 7)) (1.4.1)
# Requirement already satisfied: terminaltables in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (3.1.10)
# Requirement already satisfied: Cython in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 9)) (0.29.32)
# Collecting pycocotools
#   Downloading pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 11)) (64.0.3)
# Requirement already satisfied: pyclipper in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (1.3.0.post4)
# Requirement already satisfied: lap in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (0.4.0)
# Requirement already satisfied: motmetrics in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (1.4.0)
# Requirement already satisfied: sklearn==0.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (0.0)
# Requirement already satisfied: filterpy in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (1.4.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from sklearn==0.0->-r requirements.txt (line 19)) (0.24.2)
# Requirement already satisfied: onnx>=1.6.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (5.7.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (1.4.3)
# Collecting flask>=1.1.1
#   Downloading Flask-2.2.2-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (2.28.1)
# Requirement already satisfied: numpy in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (1.22.4)
# Requirement already satisfied: Pillow>=7.0.0 in /usr/local/lib/python3.8/dist-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (9.2.0)
# Requirement already satisfied: gradio in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (3.18.0)
# Requirement already satisfied: bce-python-sdk in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (0.8.79)
# Requirement already satisfied: x2paddle in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.8/dist-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: protobuf>=3.11.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (3.20.0)
# Requirement already satisfied: attrdict in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: tritonclient[all] in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (2.30.0)
# Requirement already satisfied: rarfile in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (4.0)
# Requirement already satisfied: multiprocess in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (0.70.14)
# Requirement already satisfied: Flask-Babel>=3.0.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (3.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (21.3)
# Requirement already satisfied: xmltodict>=0.12.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from motmetrics->-r requirements.txt (line 18)) (0.13.0)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: Jinja2>=3.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from flask>=1.1.1->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.8/dist-packages (from flask>=1.1.1->visualdl>=2.2.0->-r requirements.txt (line 3)) (8.0.4)
# Collecting Werkzeug>=2.2.2
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 35.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from flask>=1.1.1->visualdl>=2.2.0->-r requirements.txt (line 3)) (5.0.0)
# Requirement already satisfied: pytz<2023.0,>=2022.7 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from Flask-Babel>=3.0.0->visualdl>=2.2.0->-r requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: Babel<3.0.0,>=2.11.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from Flask-Babel>=3.0.0->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.37.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: setuptools-scm>=4 in /usr/local/lib/python3.8/dist-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (7.0.5)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx>=1.6.0->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.7.4.3)
# Requirement already satisfied: future>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from bce-python-sdk->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.18.2)
# Requirement already satisfied: pycryptodome>=3.8.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from bce-python-sdk->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.17)
# Requirement already satisfied: ffmpy in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: orjson in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.8.6)
# Collecting pydantic
#   Downloading pydantic-1.10.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 85.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: altair>=4.2.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.2.2)
# Requirement already satisfied: markdown-it-py[linkify,plugins]>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: python-multipart in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.0.5)
# Requirement already satisfied: aiofiles in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.8/dist-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: websockets>=10.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (10.4)
# Requirement already satisfied: pydub in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.25.1)
# Requirement already satisfied: fastapi in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.91.0)
# Requirement already satisfied: uvicorn in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.20.0)
# Requirement already satisfied: aiohttp in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.8.3)
# Requirement already satisfied: httpx in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.23.3)
# Requirement already satisfied: dill>=0.3.6 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from multiprocess->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.3.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->visualdl>=2.2.0->-r requirements.txt (line 3)) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sklearn==0.0->-r requirements.txt (line 19)) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sklearn==0.0->-r requirements.txt (line 19)) (1.2.0)
# Requirement already satisfied: python-rapidjson>=0.9.1 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.9)
# Requirement already satisfied: geventhttpclient<=2.0.2,>=1.4.4 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.0.2)
# Collecting grpcio>=1.41.0
#   Downloading grpcio-1.51.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 95.5 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from x2paddle->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.11.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.16.0)
# Requirement already satisfied: gevent>=0.13 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from geventhttpclient<=2.0.2,>=1.4.4->tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (22.10.2)
# Requirement already satisfied: brotli in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from geventhttpclient<=2.0.2,>=1.4.4->tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.9.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py[linkify,plugins]>=2.0.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.8/dist-packages (from markdown-it-py[linkify,plugins]>=2.0.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.3.1)
# Requirement already satisfied: linkify-it-py~=1.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from markdown-it-py[linkify,plugins]>=2.0.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.0.3)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from setuptools-scm>=4->matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: starlette<0.25.0,>=0.24.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from fastapi->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.24.0)
# Collecting typing-extensions>=3.6.2.1
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from httpx->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: sniffio in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from httpx->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from httpx->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.16.3)
# Requirement already satisfied: mpmath>=0.19 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from sympy->x2paddle->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: h11>=0.8 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from uvicorn->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: greenlet>=2.0.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gevent>=0.13->geventhttpclient<=2.0.2,>=1.4.4->tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: zope.event in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gevent>=0.13->geventhttpclient<=2.0.2,>=1.4.4->tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.6)
# Requirement already satisfied: zope.interface in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gevent>=0.13->geventhttpclient<=2.0.2,>=1.4.4->tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (5.5.2)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (5.10.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.3.10)
# Requirement already satisfied: uc-micro-py in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from linkify-it-py~=1.0->markdown-it-py[linkify,plugins]>=2.0.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.0.1)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (pyproject.toml): started
#   Building wheel for pycocotools (pyproject.toml): finished with status 'done'
#   Created wheel for pycocotools: filename=pycocotools-2.0.6-cp38-cp38-linux_x86_64.whl size=422900 sha256=061bb7a6b9b124376885e9fa062d66643ffd790ff50317be511e5ef795f23f57
#   Stored in directory: /home/5qx9nf8a/.cache/pip/wheels/3e/08/ac/58126fe59992032701437336493f6132e1b72381a62d00b595
# Successfully built pycocotools
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# Installing collected packages: Werkzeug, typing-extensions, opencv-python, itsdangerous, grpcio, pydantic, flask, pycocotools
#   WARNING: The script flask is installed in '/home/5qx9nf8a/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.0 which is incompatible.
# cudf 22.8.0a0+304.g6ca81bbc78.dirty requires protobuf<3.21.0a0,>=3.20.1, but you have protobuf 3.20.0 which is incompatible.
# Successfully installed Werkzeug-2.2.2 flask-2.2.2 grpcio-1.51.1 itsdangerous-2.1.2 opencv-python-4.5.5.64 pycocotools-2.0.6 pydantic-1.10.4 typing-extensions-4.4.0
# running install
# /usr/local/lib/python3.8/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# error: can't create or remove files in install directory
#
# The following error occurred while trying to add or remove files in the
# installation directory:
#
#     [Errno 30] Read-only file system: '/usr/lib/python3.8/site-packages'
#
# The installation directory you specified (via --install-dir, --prefix, or
# the distutils default setting) was:
#
#     /usr/lib/python3.8/site-packages/
#
# This directory does not currently exist.  Please create it and try again, or
# choose a different installation directory (using the -d or --install-dir
# option).

# %%
# !pip install decord
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# Requirement already satisfied: decord in /home/5qx9nf8a/.local/lib/python3.8/site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.14.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from decord) (1.22.4)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)

# %%
import os
HOME = os.getcwd()
print(HOME)
# %cd {HOME}

# %%
# !pip install Cython
import os
import numpy
import sys

# %cd bbox
# !python3 setup.py build_ext --inplace
import pyximport
pyximport.install() 
pyximport.install(setup_args={"script_args" : ["--verbose"]})
sys.path.append(f"{HOME}/bbox")
from bbox import bbox_overlaps
from IPython import display
#display.clear_output()
# %cd ../
#os.getcwd()
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# !cd ByteTrack && pip3 install -q -r requirements.txt
# !cd ByteTrack && python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric

display.clear_output()
import sys
sys.path.append(f"{HOME}/ByteTrack")
import yolox
print("yolox.__version__:", yolox.__version__)
print(numpy.version.version)
sys.path.append(f"{HOME}/ByteTrack")
sys.path.append("/home/5qx9nf8a/.local/bin")
display.clear_output()
# !git clone https://github.com/Wiqzard/hack-sordi-tracking.git
# !cd tracking-tools && git pull
sys.path.append(f"{HOME}/tracking-tools")

# %%
# !python3 -m pip install numpy==1.22.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# Collecting numpy==1.22.2
#   Using cached numpy-1.22.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
#     Found existing installation: numpy 1.24.2
#     Uninstalling numpy-1.24.2:
#       Successfully uninstalled numpy-1.24.2
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/home/5qx9nf8a/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [Errno 16] Device or resource busy: '.nfs00000000007c1e2900000189'

# %% [markdown]
# ### First transform dataset from bmw format to yolov5. Then from yolov5 to COCO.

# %% [markdown]
# # Eval

# %%
# %%bash
# cd PaddleDetection
#
# WEIGHTS=/home/5qx9nf8a/team_workspace/PaddleDetection/tracking/model_final.pdparams
# #configs=/home/5qx9nf8a/team_workspace/PaddleDetection/configs/mot/bytetrack/detector/ppyoloe_plus_m_bytetrack.yml
# CONFIGS=/home/5qx9nf8a/team_workspace/PaddleDetection/configs/ppyoloe/ppyoloe_plus_crn_m_80e_coco.yml
#
# CUDA_VISIBLE_DEVICES=0 python tools/eval.py -c ${CONFIGS} -o weights=${WEIGHTS} --amp
# Out:
# DEBUG:asyncio:Using selector: EpollSelector
# W0213 02:54:32.583552 705419 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 8.0, Driver API Version: 11.8, Runtime API Version: 11.7
# W0213 02:54:32.598774 705419 gpu_resources.cc:91] device: 0, cuDNN Version: 8.6.
# loading annotations into memory...
# Done (t=0.27s)
# creating index...
# index created!
# /usr/local/lib/python3.8/dist-packages/scipy/fft/__init__.py:97: DeprecationWarning: The module numpy.dual is deprecated.  Instead of using dual, use the functions directly from numpy or scipy.
#   from numpy.dual import register_func
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.8/dist-packages/scipy/special/orthogonal.py:81: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from numpy import (exp, inf, pi, sqrt, floor, sin, cos, around, int,
# [02/13 02:54:36] ppdet.utils.checkpoint INFO: Finish loading model weights: /home/5qx9nf8a/team_workspace/PaddleDetection/tracking/model_final.pdparams
# [02/13 02:54:37] ppdet.engine INFO: Eval iter: 0
# [02/13 02:54:41] ppdet.engine INFO: Eval iter: 100
# [02/13 02:54:45] ppdet.engine INFO: Eval iter: 200
# [02/13 02:54:48] ppdet.engine INFO: Eval iter: 300
# [02/13 02:54:52] ppdet.engine INFO: Eval iter: 400
# [02/13 02:54:56] ppdet.engine INFO: Eval iter: 500
# [02/13 02:55:00] ppdet.engine INFO: Eval iter: 600
# [02/13 02:55:03] ppdet.engine INFO: Eval iter: 700
# [02/13 02:55:07] ppdet.engine INFO: Eval iter: 800
# [02/13 02:55:12] ppdet.engine INFO: Eval iter: 900
# [02/13 02:55:16] ppdet.engine INFO: Eval iter: 1000
# [02/13 02:55:19] ppdet.engine INFO: Eval iter: 1100
# [02/13 02:55:23] ppdet.engine INFO: Eval iter: 1200
# [02/13 02:55:26] ppdet.engine INFO: Eval iter: 1300
# [02/13 02:55:30] ppdet.engine INFO: Eval iter: 1400
# [02/13 02:55:43] ppdet.metrics.metrics INFO: The bbox result is saved to bbox.json.
# loading annotations into memory...
# Done (t=0.16s)
# creating index...
# index created!
# [02/13 02:55:43] ppdet.metrics.coco_utils INFO: Start evaluate...
# Loading and preparing results...
# DONE (t=5.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=101.39s).
# Accumulating evaluation results...
# DONE (t=5.87s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.877
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.933
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.918
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.436
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.921
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.862
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.915
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.694
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.959
# [02/13 02:57:36] ppdet.engine INFO: Total sample number: 2999, averge FPS: 51.284046333001776

# %% [markdown]
# # Export

# %%
# %%bash
# cd PaddleDetection
#
# CONFIGS=/home/5qx9nf8a/team_workspace/PaddleDetection/configs/ppyoloe/ppyoloe_plus_crn_m_80e_coco.yml
# WEIGHTS=/home/5qx9nf8a/team_workspace/PaddleDetection/tracking/model_final.pdparams
#
# python tools/export_model.py -c ${CONFIGS} -o weights=${WEIGHTS} trt=True
# Out:
# [02/12 16:41:59] ppdet.utils.checkpoint INFO: Finish loading model weights: /home/5qx9nf8a/team_workspace/PaddleDetection/tracking/model_final.pdparams
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
# [02/12 16:41:59] ppdet.engine INFO: Export inference config file to output_inference/ppyoloe_plus_crn_m_80e_coco/infer_cfg.yml
# [02/12 16:42:05] ppdet.engine INFO: Export model and saved in output_inference/ppyoloe_plus_crn_m_80e_coco
# /usr/local/lib/python3.8/dist-packages/scipy/fft/__init__.py:97: DeprecationWarning: The module numpy.dual is deprecated.  Instead of using dual, use the functions directly from numpy or scipy.
#   from numpy.dual import register_func
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.8/dist-packages/scipy/special/orthogonal.py:81: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from numpy import (exp, inf, pi, sqrt, floor, sin, cos, around, int,

# %% [markdown]
# # Test TRT Inference

# %%
# %%bash
# cd PaddleDetection
#
# MODEL_DIR=/home/5qx9nf8a/team_workspace/PaddleDetection/output_inference/ppyoloe_plus_crn_m_80e_coco
# VIDEO_PATH=/home/5qx9nf8a/team_workspace/data/Hackathon_Stage2/Evaluation_set/video/eval_video_1.mp4 #--video_file=${VIDEO_PATH}
# IMAGE_PATH=/home/5qx9nf8a/team_workspace/data/Hackathon_Stage2/Evaluation_set/dataset/images/124.jpg
#
# CUDA_VISIBLE_DEVICES=0 python deploy/python/infer.py --model_dir=${MODEL_DIR} --image_file=${IMAGE_PATH} --run_mode=trt_fp16 --device=gpu --run_benchmark=True
# Out:
# Error while terminating subprocess (pid=102338):

# %% [markdown]
# # Video Processing (Detection + Tracking + Scanning + Annotating)

# %%
from decord import VideoReader, cpu, gpu
import numpy as np
from typing import Generator
import itertools
import sys
from video_tools.source import generate_shifted_frames


def get_video_frames_batch_generator_v2(
    video_path: str, batch_size: int = 1, stride: int = 8, reduction_factor: int = 1
) -> Generator:
    """
    Returns a generator that yields the frames of the video in batches.

    :param video_path: str : The path of the video file.
    :param batch_size: int : The size of the batch.
    :return: Generator : Generator that yields the frames of the video in batches.
    """   
    vr = VideoReader(video_path, ctx=cpu(0))
    total_frames = len(vr)
    frames_list = list(range(0, total_frames, reduction_factor))
    saved_count = 0
    last_frame = vr[-1].asnumpy()
    hor_size = last_frame.shape[1]
    extra_frames = int(0.85 * 1280/stride)
    shifted_frames_generator = generate_shifted_frames(last_frame, int(0.85 * hor_size), stride)
    announced = False
    for idx in range(0, len(frames_list) + extra_frames, batch_size):
        if idx >= len(frames_list):
            if not announced:
                print("This is the last frame.")
                announced = True
            frames = np.array(list(itertools.islice(shifted_frames_generator, batch_size)))
            if frames.shape[0] != batch_size:
                continue
            yield frames
        else:
            yield vr.get_batch(frames_list[idx:idx+batch_size]).asnumpy()

# %%
from dataclasses import dataclass, field
from __future__ import annotations


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.2 #0.4
    track_buffer: int = 30
    match_thresh: float = 0.7 #0.7
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

@dataclass(frozen=True)
class Args:
    #BYTE_TRACKER_ARGS: BYTETrackerArgs = field(default_factory=lambda:BYTETrackerArgs())
    BYTE_TRACKER_ARGS = BYTETrackerArgs
    STRIDE: int = 8
    REDUCTION_FACTOR: int = 3
    SOURCE_VIDEO_PATH: str = (
        "data/Hackathon_Stage2/Evaluation_set/video/eval_video_1.mp4"
    )
    TARGET_VIDEO_PATH: str = "/temp/eval_video_1.mp4"
    MODEL_DIR: str = "/home/5qx9nf8a/team_workspace/PaddleDetection/output_inference/ppyoloe_plus_crn_m_80e_coco"
    BATCH_SIZE: int = 32
    RUN_MODE: str = "trt_fp16" #"paddle", "trt_int8"
    CPU_THREADS: int = 1
    MAX_DETECTIONS: int = 300
    CLASS_NAMES_DICT: dict = field(
        default_factory=lambda:{
            0: "klt_box_empty",
            1: "klt_box_full",
            2: "rack_1",
            3: "rack_2",
            4: "rack_3",
            5: "rack_4",
            6: "placeholder",
        }
    )

    SCANNER_X: int = 300
    SCANNER_Y: int = 50
    BOX_THRESHOLD: float = 0.35
    RACK_THRESHOLD: float = 0.79

args = Args()

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
# Out:
# INFO:root:test

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

from typing import Generator, Tuple, Any, Union
import os
import cv2
import numpy as np
from tqdm import tqdm
from pathlib import Path
import logging
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
from functools import partial
#import pickle
#import concurrent.futures
import multiprocessing as mp
import paddle
paddle.utils.run_check()

from PaddleDetection.deploy.python.infer import Detector
from ByteTrack.yolox.tracker.byte_tracker import BYTETracker

from video_tools.video_info import VideoInfo
from video_tools.sink import VideoSink
from tracking.rack_counter_new import RackScanner, ScannerCounterAnnotator
from tracking.tracking_utils import detections2boxes, match_detections_with_tracks
from tracking.tracking_counter import create_submission_dict, write_submission
from detection.detection_tools import BoxAnnotator, Detections, process_placeholders
from draw.color import ColorPalette, Color
from geometry.geometry import Point


Frame = np.ndarray
Path = Union[str, Path]

class VideoProcessor:
    """
    A class to detect and track objects in a video.
    ...

    Attributes
    ----------
    args : Args
        contains all the necessary information
    source_video_path : str | Path
        path of the video source
    target_video_path : str | Path
        path where the result is written

    Methods
    -------
    info(additional=""):
        Prints the person's name and age.
    """
    
    def __init__(
        self,
        args: Args,
        source_video_path: Union[str, Path],
        target_dir: Union[str, Path]="/temp/"
    ) -> None:
        self.args = args
        
        if not os.path.exists(source_video_path) or not source_video_path.endswith(".mp4"):
            raise ValueError("Invalid source video path")
        self.source_video_path = source_video_path
        
        self.target_dir = os.path.dirname(target_dir)
        #os.makedirs(target_dir, exist_ok=True)
        
        self.target_video_path = os.path.join(target_dir, "processed_eval_video.mp4")
                
        logger.info("<---------- BUILD VIDEOPROCESSOR ---------->")
        self.video_info: VideoInfo = VideoInfo.from_video_path(self.source_video_path)
        self._frame_shape: Tuple[int, int] = self.video_info.shape
        self.video_sink: VideoSink = VideoSink(self.target_video_path, self.args.REDUCTION_FACTOR, self.video_info)
        
        #self.detector: Detector = self._build_detector()
        self.tracker: Tracker = self._build_tracker()
        self.scanner: Scanner = self._build_scanner()
        self.box_annotator: BoxAnnotator = self._build_box_annotator()
        self.scanner_annotator: ScannerAnnotator = self._build_scanner_annotator()
        logger.info("<--------- INITILIAZATION COMPLETE ---------> \n")
    


    def _build_detector(self) -> Detector:
        logger.info("*** BUILD DETECTOR ***")
        return Detector(model_dir=self.args.MODEL_DIR,
                 device='GPU',
                 run_mode=self.args.RUN_MODE,
                 batch_size=self.args.BATCH_SIZE,
                 trt_min_shape=1,
                 trt_max_shape=1280,
                 trt_opt_shape=640,
                 trt_calib_mode=False,
                 cpu_threads=self.args.CPU_THREADS,
                 enable_mkldnn=False,
                 enable_mkldnn_bfloat16=False,
                 output_dir='output_paddle',
                 threshold=0.5,
                 delete_shuffle_pass=False)
    
    def _build_tracker(self) -> BYTETracker:
        logger.info("*** BUILD TRACKER ***")
        return BYTETracker(self.args.BYTE_TRACKER_ARGS())
    
    def _build_scanner(self) -> RackScanner:
        logger.info("*** BUILD SCANNER ***")
        return RackScanner(Point(x=self.args.SCANNER_X, y=self.args.SCANNER_Y), 620)

    def _build_box_annotator(self) -> BoxAnnotator:
        logger.info("*** BUILD BOX ANNOTATOR ***")
        return BoxAnnotator(
                color=ColorPalette(),
                thickness=2,
                text_thickness=1,
                text_scale=0.3,
                text_padding=2,
            )
    
    def _build_scanner_annotator(self) -> ScannerCounterAnnotator:
        logger.info("*** BUILD SCNANER ANNOTATOR ***")
        return ScannerCounterAnnotator(
                thickness=2,
                color=Color.white(),
                text_thickness=2,
                text_color=Color.red(),
                text_scale=0.6,
                text_offset=1.5,
                text_padding=10,
            )
              
    def _build_generator(self) -> Generator:
        return get_video_frames_batch_generator_v2(
            self.source_video_path, batch_size=self.args.BATCH_SIZE, stride=self.args.STRIDE, reduction_factor=self.args.REDUCTION_FACTOR
        )
    def _infer_batch(self, detector, batch: List[Frame]) -> List[Detection]:
        inputs = detector.preprocess(batch)
        detector.predictor.run()
        results = self.postprocess(detector)
        return results
    
    def create_submission(self, mAP: float, fps: float, save: bool=False) -> dict:
        """mAP in percent points"""
        if fps < 25 or mAP < 10:
            raise ValueError("fps or mAP in wrong format")
        submission_dict = create_submission_dict(scanned_racks=self.scanner.rack_tracks, mAP=mAP, fps=fps)
        if save:
            submission_path = os.path.join(self.target_dir, "AcademicWeapons.json")
            write_submission(submission_dict=submission_dict, submission_path=submission_path)
        return submission_dict
    
    def postprocess(self, detector):
        np_boxes_num, np_boxes, np_masks = np.array([0]), None, None
        output_names = detector.predictor.get_output_names()
        boxes_tensor = detector.predictor.get_output_handle(output_names[0])
        np_boxes = boxes_tensor.copy_to_cpu()
        boxes_num = detector.predictor.get_output_handle(output_names[1])
        np_boxes_num = boxes_num.copy_to_cpu()

        result = dict(boxes=np_boxes, masks=np_masks, boxes_num=np_boxes_num)
        np_boxes_num = result['boxes_num']
        if not isinstance(np_boxes_num, np.ndarray):
            raise ValueError("np_boxes_num` should be a `numpy.ndarray`")

        if np_boxes_num.sum() <= 0:
            logger.warning('[WARNNING] No object detected.')
            result = {'boxes': np.zeros([0, 6]), 'boxes_num': np_boxes_num}
        result = {k: v for k, v in result.items() if v is not None}
        return result

    def process_video(self, detector, with_scanner: bool=True, with_placeholders: bool=True, with_annotate_scanner: bool=True) -> None:
        self.with_scanner, self.with_placeholders = with_scanner, with_placeholders
              
        generator = self._build_generator()
        with self.video_sink as sink:
            for idx, batch in tqdm(
                enumerate(generator),
                total=int(self.video_info.total_frames / self.args.BATCH_SIZE/ self.args.REDUCTION_FACTOR),
            ):
                if batch is None:
                    continue
                results = self._infer_batch(detector, batch)
                # Run detector in batches

               # Process each frame in batch
               # with ProcessPoolExecutor(max_workers=self.args.BATCH_SIZE) as executor:
                with ThreadPoolExecutor() as executor:
                    frames_gen = ((i, frame) for i, frame in enumerate(batch))
                    #results_gen = executor.map(partial(self._initial_results_to_detections, results), range(len(batch)))
                    results_gen = ((self._initial_results_to_detections(results, i)) for  i in range(len(batch)))
                    detections_dict: dict[int, Detections] = {key: value for key, value in results_gen}
                    
                    if len(detections_dict) == 0:
                        frames = dict(frames_gen)
                        for i in len(batch):
                            sink.write_frame(frames[i])
                        continue
                    
                    detections_dict = {i : self._get_tracks(detections_dict[i]) for i in range(len(batch))}
                    if with_scanner and not with_annotate_scanner:
                        temp = [self._update_scanner(detections_dict[i]) for i in range(len(batch))]
                    if with_scanner and with_annotate_scanner:
                        frames_gen = (self._annotate_scanner(batch[i], i) for i  in range(len(batch)) if not self._update_scanner(detections_dict[i]))

                    # if tracks
                    #if not all(val is None for val in detections_dict.values()):
                    #    if with_scanner and with_annotate_scanner: 
                    #        frames_gen: Generator[int, Frame] = executor.map(self._annotate_scanner, batch, range(len(batch)))

                        frames_detections_gen = ((i, frame, detections_dict[i]) for i, frame in frames_gen)
                        if with_placeholders:
                            frames_gen = executor.map(self._annotate_placeholders, frames_detections_gen) 

                        frames_detections_gen = ((i, frame, detections_dict[i]) for i, frame in frames_gen)
                        frames_gen = executor.map(self._annotate_detections, frames_detections_gen)
                    frames_ordered = sorted(list(frames_gen), key=lambda x: x[0])#xist(frames_gen).sort(key=lambda x: x[0])
                    frames_ordered = [x[1] for x in frames_ordered] 

                    for frame in frames_ordered:
                        sink.write_frame(frame)

    def sort_indexed_tuple(self, tup: Tuple[Tuple[int, Any]]):
        tup.sort(key=lambda x: x[0]) 
        return tup 

    def _initial_results_to_detections(self, results, idx: int) -> Tuple[int, Detections]:
        boxes = results['boxes'][idx*self.args.MAX_DETECTIONS : (idx+1) * self.args.MAX_DETECTIONS, :]
        boxes = boxes[boxes[:,1] > self.args.BOX_THRESHOLD]
        detections = Detections(
                xyxy=boxes[:,2:],
                confidence=boxes[:,1],
                class_id=boxes[:,0].astype(int)
            )
        # filter where center of box below threshold
        position_mask = (detections.xyxy[:,1] + (detections.xyxy[:, 3] - detections.xyxy[:, 1])/2) < 600
        area_mask = ((detections.xyxy[:, 2] - detections.xyxy[:, 0]) * (detections.xyxy[:, 3] - detections.xyxy[:, 1]) < 2500)
        mask_conf_klt =  np.isin(detections.class_id, [0, 1])
        mask_klt = np.logical_and(area_mask, mask_conf_klt)
        mask_conf_rack = np.logical_and(detections.confidence > self.args.RACK_THRESHOLD, np.isin(detections.class_id, [2, 3, 4, 5]))
        mask = np.logical_and(np.logical_or(mask_conf_klt, mask_conf_rack), position_mask)
        
        detections.filter(mask=mask, inplace=True)
        return (idx, detections)
    
    def _get_tracks(self, detections: Detections) -> Detections:
        tracks = self.tracker.update(
                output_results=detections2boxes(detections=detections),
                img_info=self.video_info.shape,
                img_size=self.video_info.shape
            )
        if len(detections) == 0 and len(tracks) == 0:
            return detections

        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)

        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        return detections
    
    def _annotate_placeholders(self, frame_detections) -> Union[int, Frame]:
        
        idx, frame, detections = frame_detections
        placeholders, placeholder_labels= process_placeholders(detections, self.scanner.scanner.x)
        if placeholders and placeholder_labels:
            frame = self.box_annotator.annotate(
                    frame=frame, detections=placeholders, labels=placeholder_labels
                )   
        return idx, frame#, detections
        
              
    def _annotate_detections(self, frame_detections: Tuple[int, Frame, Detections]) -> Tuple[int, Frame]:
        idx, frame, detections = frame_detections
        labels = [
            f"#{tracker_id} {self.args.CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections]
        # annotatoe detection boxes
        frame = self.box_annotator.annotate(
            frame=frame, detections=detections, labels=labels
        )
        #print(frame.shape)
        return idx, frame
    
    def _update_scanner(self, detections: Detections) -> None:
        self.scanner.update(detections)
              
    def _annotate_scanner(self, frame: Frame, idx: int) -> Tuple[int, Frame]:
        return idx, self.scanner_annotator.annotate(frame=frame, rack_scanner=self.scanner)
# Out:
# E0000 00:00:00.000000 693094 dir_reader_linux.h:41] RAW: Failed to close directory handle
# Running verify PaddlePaddle program ...
# W0213 02:44:53.977449 691503 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 8.0, Driver API Version: 11.8, Runtime API Version: 11.7
# W0213 02:44:53.982172 691503 gpu_resources.cc:91] device: 0, cuDNN Version: 8.6.
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle works well on 1 GPUs.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.
# /usr/local/lib/python3.8/dist-packages/scipy/fft/__init__.py:97: DeprecationWarning: The module numpy.dual is deprecated.  Instead of using dual, use the functions directly from numpy or scipy.
#   from numpy.dual import register_func
# /usr/local/lib/python3.8/dist-packages/scipy/special/orthogonal.py:81: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from numpy import (exp, inf, pi, sqrt, floor, sin, cos, around, int,
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /teams/hack_team_09/workspace/ByteTrack/yolox/tracker/matching.py:7: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from cython_bbox import bbox_overlaps as bbox_ious

# %%
if __name__ == "__main__":  
    SOURCE_VIDEO_PATH = "data/live_demo/Evaluation_set/demo_eval_video/full_eval_demo_video.mp4"#"data/Hackathon_Stage2/Evaluation_set/video/eval_video_1.mp4"
    TARGET_VIDEO_PATH = "/home/5qx9nf8a/team_workspace/temp/"
    detector = Detector(model_dir=args.MODEL_DIR,
                 device='GPU',
                 run_mode=args.RUN_MODE,
                 batch_size=args.BATCH_SIZE,
                 trt_min_shape=1,
                 trt_max_shape=1280,
                 trt_opt_shape=640,
                 trt_calib_mode=False,
                 cpu_threads=args.CPU_THREADS,
                 enable_mkldnn=False,
                 enable_mkldnn_bfloat16=False,
                 output_dir='output_paddle',
                 threshold=0.3,
                 delete_shuffle_pass=False)
    
    video_processor = VideoProcessor(source_video_path = SOURCE_VIDEO_PATH, 
                                    target_dir = TARGET_VIDEO_PATH,
                                    args = args)
    video_processor.process_video(detector, with_scanner=True, with_placeholders=True, with_annotate_scanner=True)
# Out:
# -----------  Model Configuration -----------
# Model Arch: YOLO
# Transform Order:
# --transform op: Resize
# --transform op: NormalizeImage
# --transform op: Permute
# --------------------------------------------
# INFO:root:<---------- BUILD VIDEOPROCESSOR ---------->
# INFO:root:*** BUILD TRACKER ***
# INFO:root:*** BUILD SCANNER ***
# INFO:root:*** BUILD BOX ANNOTATOR ***
# INFO:root:*** BUILD SCNANER ANNOTATOR ***
# INFO:root:<--------- INITILIAZATION COMPLETE --------->
# <---------- Processing video ---------->
# 100it [01:30,  1.35it/s]
# This is the last frame.
# 104it [01:32,  1.12it/s]
# Elapsed time: 92.49 seconds for 9589 frames
# Average FPS: 103.68 frames per second

# %%
video_processor.create_submission(mAP=93.3, fps=103.68, save=True)
# Out:
# {'eval_video': [{'rack_name': 'rack_1',
#    'rack_conf': 0.983929,
#    'N_full_KLT': 14,
#    'N_empty_KLT': 11,
#    'N_Pholders': 23,
#    'shelf_N_Pholders': {'shelf_1': 6,
#     'shelf_2': 8,
#     'shelf_3': 1,
#     'shelf_4': 8}},
#   {'rack_name': 'rack_2',
#    'rack_conf': 0.961904,
#    'N_full_KLT': 8,
#    'N_empty_KLT': 7,
#    'N_Pholders': 24,
#    'shelf_N_Pholders': {'shelf_1': 6,
#     'shelf_2': 4,
#     'shelf_3': 9,
#     'shelf_4': 5}},
#   {'rack_name': 'rack_4',
#    'rack_conf': 0.984042,
#    'N_full_KLT': 6,
#    'N_empty_KLT': 7,
#    'N_Pholders': 3,
#    'shelf_N_Pholders': {'shelf_1': 1, 'shelf_3': 1, 'shelf_4': 1}},
#   {'rack_name': 'rack_3',
#    'rack_conf': 0.984296,
#    'N_full_KLT': 2,
#    'N_empty_KLT': 4,
#    'N_Pholders': 0,
#    'shelf_N_Pholders': {}},
#   {'rack_name': 'rack_3',
#    'rack_conf': 0.984311,
#    'N_full_KLT': 2,
#    'N_empty_KLT': 2,
#    'N_Pholders': 2,
#    'shelf_N_Pholders': {'shelf_2': 1, 'shelf_3': 1}},
#   {'rack_name': 'rack_4',
#    'rack_conf': 0.985188,
#    'N_full_KLT': 5,
#    'N_empty_KLT': 6,
#    'N_Pholders': 5,
#    'shelf_N_Pholders': {'shelf_1': 1,
#     'shelf_2': 1,
#     'shelf_3': 1,
#     'shelf_4': 1,
#     'shelf_5': 1}},
#   {'rack_name': 'rack_1',
#    'rack_conf': 0.946469,
#    'N_full_KLT': 15,
#    'N_empty_KLT': 9,
#    'N_Pholders': 24,
#    'shelf_N_Pholders': {'shelf_1': 5,
#     'shelf_2': 5,
#     'shelf_3': 7,
#     'shelf_4': 7}},
#   {'rack_name': 'rack_2',
#    'rack_conf': 0.967577,
#    'N_full_KLT': 13,
#    'N_empty_KLT': 5,
#    'N_Pholders': 21,
#    'shelf_N_Pholders': {'shelf_1': 5,
#     'shelf_2': 3,
#     'shelf_3': 9,
#     'shelf_4': 4}},
#   {'rack_name': 'rack_1',
#    'rack_conf': 0.986651,
#    'N_full_KLT': 13,
#    'N_empty_KLT': 7,
#    'N_Pholders': 28,
#    'shelf_N_Pholders': {'shelf_1': 9,
#     'shelf_2': 8,
#     'shelf_3': 5,
#     'shelf_4': 6}},
#   {'rack_name': 'rack_3',
#    'rack_conf': 0.983814,
#    'N_full_KLT': 3,
#    'N_empty_KLT': 2,
#    'N_Pholders': 1,
#    'shelf_N_Pholders': {'shelf_2': 1}},
#   {'rack_name': 'rack_3',
#    'rack_conf': 0.984389,
#    'N_full_KLT': 3,
#    'N_empty_KLT': 3,
#    'N_Pholders': 0,
#    'shelf_N_Pholders': {}},
#   {'rack_name': 'rack_1',
#    'rack_conf': 0.975007,
#    'N_full_KLT': 10,
#    'N_empty_KLT': 7,
#    'N_Pholders': 31,
#    'shelf_N_Pholders': {'shelf_1': 8,
#     'shelf_2': 10,
#     'shelf_3': 6,
#     'shelf_4': 7}},
#   {'rack_name': 'rack_2',
#    'rack_conf': 0.976335,
#    'N_full_KLT': 8,
#    'N_empty_KLT': 1,
#    'N_Pholders': 30,
#    'shelf_N_Pholders': {'shelf_1': 9,
#     'shelf_2': 9,
#     'shelf_3': 8,
#     'shelf_4': 4}},
#   {'rack_name': 'rack_2',
#    'rack_conf': 0.97726,
#    'N_full_KLT': 4,
#    'N_empty_KLT': 10,
#    'N_Pholders': 25,
#    'shelf_N_Pholders': {'shelf_1': 6,
#     'shelf_2': 3,
#     'shelf_3': 9,
#     'shelf_4': 7}},
#   {'rack_name': 'rack_4',
#    'rack_conf': 0.977735,
#    'N_full_KLT': 5,
#    'N_empty_KLT': 5,
#    'N_Pholders': 6,
#    'shelf_N_Pholders': {'shelf_1': 3,
#     'shelf_2': 1,
#     'shelf_3': 1,
#     'shelf_5': 1}},
#   {'rack_name': 'rack_4',
#    'rack_conf': 0.985276,
#    'N_full_KLT': 7,
#    'N_empty_KLT': 4,
#    'N_Pholders': 5,
#    'shelf_N_Pholders': {'shelf_1': 1, 'shelf_3': 1, 'shelf_4': 3}},
#   {'rack_name': 'rack_3',
#    'rack_conf': 0.9811,
#    'N_full_KLT': 3,
#    'N_empty_KLT': 2,
#    'N_Pholders': 1,
#    'shelf_N_Pholders': {'shelf_1': 1}}],
#  'mAP': 93.3,
#  'FPS': 103.68}

# %% [markdown]
# {'eval_video': [{'rack_name': 'rack_1',
#    'rack_conf': 0.976074,
#    'N_full_KLT': 13,
#    'N_empty_KLT': 9,
#    'N_Pholders': 26,
#    'shelf_N_Pholders': {'shelf_1': 8,
#     'shelf_2': 8,
#     'shelf_3': 2,
#     'shelf_4': 8}},
#   {'rack_name': 'rack_2',
#    'rack_conf': 0.955078,
#    'N_full_KLT': 5,
#    'N_empty_KLT': 4,
#    'N_Pholders': 30,
#    'shelf_N_Pholders': {'shelf_1': 7,
#     'shelf_2': 7,
#     'shelf_3': 9,
#     'shelf_4': 7}},
#   {'rack_name': 'rack_4',
#    'rack_conf': 0.973633,
#    'N_full_KLT': 6,
#    'N_empty_KLT': 7,
#    'N_Pholders': 3,
#    'shelf_N_Pholders': {'shelf_1': 1, 'shelf_3': 1, 'shelf_4': 1}},
#   {'rack_name': 'rack_3',
#    'rack_conf': 0.971191,
#    'N_full_KLT': 2,
#    'N_empty_KLT': 4,
#    'N_Pholders': 0,
#    'shelf_N_Pholders': {}},
#   {'rack_name': 'rack_3',
#    'rack_conf': 0.969238,
#    'N_full_KLT': 2,
#    'N_empty_KLT': 2,
#    'N_Pholders': 2,
#    'shelf_N_Pholders': {'shelf_2': 1, 'shelf_3': 1}},
#   {'rack_name': 'rack_4',
#    'rack_conf': 0.966309,
#    'N_full_KLT': 5,
#    'N_empty_KLT': 5,
#    'N_Pholders': 6,
#    'shelf_N_Pholders': {'shelf_1': 1,
#     'shelf_2': 1,
#     'shelf_3': 2,
#     'shelf_4': 1,
#     'shelf_5': 1}},
#   {'rack_name': 'rack_1',
#    'rack_conf': 0.964355,
#    'N_full_KLT': 15,
#    'N_empty_KLT': 10,
#    'N_Pholders': 23,
#    'shelf_N_Pholders': {'shelf_1': 5,
#     'shelf_2': 6,
#     'shelf_3': 6,
#     'shelf_4': 6}},
#   {'rack_name': 'rack_2',
#    'rack_conf': 0.978027,
#    'N_full_KLT': 12,
#    'N_empty_KLT': 5,
#    'N_Pholders': 22,
#    'shelf_N_Pholders': {'shelf_1': 6,
#     'shelf_2': 3,
#     'shelf_3': 9,
#     'shelf_4': 4}}],
#  'mAP': 96.3,
#  'FPS': 0}

# %%
# %%bash
# cd PaddleDetection/PaddleYOLO
# pwd
#
# model_name=ppyoloe
# job_name=ppyoloe_plus_crn_m_80e_coco
#
# config=/home/5qx9nf8a/team_workspace/PaddleDetection/PaddleYOLO/configs/custom/ppyoloe_plus_crn_m_80e_coco.yml #/configs/custom/${job_name}.yml
# log_dir=log_dir/${job_name}
# weights=output/${job_name}/model_final.pdparams
# video_path=/home/5qx9nf8a/team_workspace/data/Hackathon_Stage2/Evaluation_set/video/eval_video_1.mp4
# img_folder=/home/5qx9nf8a/team_workspace/data/trans_data/val/images/
# # 1.training（single GPU / multi GPU）
# # CUDA_VISIBLE_DEVICES=0 python tools/train.py -c ${config} --eval --amp
#
# # 2.eval
# #CUDA_VISIBLE_DEVICES=0 python tools/eval.py -c ${config} -o weights=${weights} --classwise
#
# # 3.infer
# #CUDA_VISIBLE_DEVICES=0 python tools/infer.py -c ${config} -o weights=${weights} --infer_dir=${img_folder} --draw_threshold=0.5
#
#
# # 4.export
# CUDA_VISIBLE_DEVICES=0 python tools/export_model.py -c ${config} -o weights=${weights} # trt=True
#
# # CUDA_VISIBLE_DEVICES=0 python tools/export_model.py -c ${config} -o weights=${weights} exclude_post_process=True # trt=True
#
# # CUDA_VISIBLE_DEVICES=0 python tools/export_model.py -c ${config} -o weights=${weights} exclude_nms=True # trt=True
#
# # 5.deploy infer
# #CUDA_VISIBLE_DEVICES=0 python deploy/python/infer.py --model_dir=output_inference/${job_name} --image_file=demo/000000014439_640x640.jpg --device=GPU
#
# # 6.deploy speed, add '--run_mode=trt_fp16' to test in TensorRT FP16 mode
# #CUDA_VISIBLE_DEVICES=0 python deploy/python/infer.py --model_dir=output_inference/${job_name} --image_file=demo/000000014439_640x640.jpg --device=GPU --run_benchmark=True # --run_mode=trt_fp16
#
# # 7.export onnx
# #paddle2onnx --model_dir output_inference/${job_name} --model_filename model.pdmodel --params_filename model.pdiparams --opset_version 12 --save_file ${job_name}.onnx
#
# # 8.onnx speed
# #/usr/local/TensorRT-8.0.3.4/bin/trtexec --onnx=${job_name}.onnx --workspace=4096 --avgRuns=10 --shapes=input:1x3x640x640 --fp16
# #/usr/local/TensorRT-8.0.3.4/bin/trtexec --onnx=${job_name}.onnx --workspace=4096 --avgRuns=10 --shapes=input:1x3x640x640 --fp32
# Out:
# /teams/hack_team_09/workspace/PaddleDetection/PaddleYOLO
# Traceback (most recent call last):
#   File "tools/infer.py", line 236, in <module>
#     main()
#   File "tools/infer.py", line 232, in main
#     run(FLAGS, cfg)
#   File "tools/infer.py", line 160, in run
#     trainer = Trainer(cfg, mode='test')
#   File "/teams/hack_team_09/workspace/PaddleDetection/PaddleYOLO/ppdet/engine/trainer.py", line 80, in __init__
#     self.dataset = self.cfg['{}Dataset'.format(capital_mode)] = create(
#   File "/teams/hack_team_09/workspace/PaddleDetection/PaddleYOLO/ppdet/core/workspace.py", line 283, in create
#     return cls(**cls_kwargs)
#   File "/teams/hack_team_09/workspace/PaddleDetection/PaddleYOLO/ppdet/data/source/dataset.py", line 278, in __init__
#     type = dataset_args.pop("name")
# KeyError: 'name'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd PaddleDetection/PaddleYOLO\npwd\n\nmodel_name=ppyoloe \njob_name=ppyoloe_plus_crn_m_80e_coco \n\nconfig=/home/5qx9nf8a/team_workspace/PaddleDetection/PaddleYOLO/configs/custom/ppyoloe_plus_crn_m_80e_coco.yml #/configs/custom/${job_name}.yml\nlog_dir=log_dir/${job_name}\nweights=output/${job_name}/model_final.pdparams\nvideo_path=/home/5qx9nf8a/team_workspace/data/Hackathon_Stage2/Evaluation_set/video/eval_video_1.mp4\nimg_folder=/home/5qx9nf8a/team_workspace/data/trans_data/val/images/\n\nCUDA_VISIBLE_DEVICES=0 python tools/infer.py -c ${config} -o weights=${weights} --infer_dir=${img_folder} --draw_threshold=0.5\n\n\n\n')
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2422, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2420 with self.builtin_trap:
#    2421     args = (magic_arg_s, cell)
# -> 2422     result = fn(*args, **kwargs)
#    2423 return result
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'cd PaddleDetection/PaddleYOLO\npwd\n\nmodel_name=ppyoloe \njob_name=ppyoloe_plus_crn_m_80e_coco \n\nconfig=/home/5qx9nf8a/team_workspace/PaddleDetection/PaddleYOLO/configs/custom/ppyoloe_plus_crn_m_80e_coco.yml #/configs/custom/${job_name}.yml\nlog_dir=log_dir/${job_name}\nweights=output/${job_name}/model_final.pdparams\nvideo_path=/home/5qx9nf8a/team_workspace/data/Hackathon_Stage2/Evaluation_set/video/eval_video_1.mp4\nimg_folder=/home/5qx9nf8a/team_workspace/data/trans_data/val/images/\n\nCUDA_VISIBLE_DEVICES=0 python tools/infer.py -c ${config} -o weights=${weights} --infer_dir=${img_folder} --draw_threshold=0.5\n\n\n\n'' returned non-zero exit status 1.

# %%
# !git clone https://github.com/PaddlePaddle/PaddleYOLO  # clone
# !cd PaddleYOLO
# !pip install -r requirements.txt
# Out:
# Cloning into 'PaddleYOLO'...
# remote: Enumerating objects: 26278, done.
# remote: Counting objects: 100% (1825/1825), done.
# remote: Compressing objects: 100% (477/477), done.
# remote: Total 26278 (delta 1431), reused 1649 (delta 1348), pack-reused 24453
# Receiving objects: 100% (26278/26278), 306.03 MiB | 30.88 MiB/s, done.
# Resolving deltas: 100% (19190/19190), done.
# Updating files: 100% (661/661), done.
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -rotobuf (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tqdm in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (4.64.1)
# Requirement already satisfied: typeguard in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (2.13.3)
# Requirement already satisfied: visualdl>=2.2.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (2.5.0)
# Collecting opencv-python<=4.6.0
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 105.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyYAML in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (6.0)
# Requirement already satisfied: shapely in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: scipy in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (1.10.0)
# Requirement already satisfied: terminaltables in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (3.1.10)
# Requirement already satisfied: Cython in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (0.29.33)
# Requirement already satisfied: pycocotools in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (2.0+nv0.6.0)
# Requirement already satisfied: setuptools in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (66.1.1)
# Requirement already satisfied: pyclipper in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (1.3.0.post4)
# Requirement already satisfied: lap in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (0.4.0)
# Requirement already satisfied: motmetrics in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (1.4.0)
# Collecting sklearn==0.0
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filterpy in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (1.4.5)
# Requirement already satisfied: scikit-learn in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from sklearn==0.0->-r requirements.txt (line 19)) (1.1.1)
# Requirement already satisfied: x2paddle in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: matplotlib in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (3.6.3)
# Requirement already satisfied: rarfile in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (4.0)
# Requirement already satisfied: Flask-Babel>=3.0.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (3.0.1)
# Requirement already satisfied: onnx>=1.6.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: tritonclient[all] in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (2.30.0)
# Requirement already satisfied: six>=1.14.0 in /opt/conda/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: requests in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (2.28.2)
# Requirement already satisfied: psutil in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (5.9.4)
# Requirement already satisfied: protobuf>=3.11.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (3.20.0)
# Requirement already satisfied: bce-python-sdk in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (0.8.79)
# Requirement already satisfied: packaging in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (23.0)
# Requirement already satisfied: numpy in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (1.24.2)
# Requirement already satisfied: attrdict in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: gradio in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (3.18.0)
# Requirement already satisfied: Pillow>=7.0.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: multiprocess in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (0.70.14)
# Requirement already satisfied: pandas in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (1.5.2)
# Requirement already satisfied: flask>=1.1.1 in /opt/conda/lib/python3.8/site-packages (from visualdl>=2.2.0->-r requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: pybind11>=2.2 in /opt/conda/lib/python3.8/site-packages (from pycocotools->-r requirements.txt (line 10)) (2.9.2)
# Requirement already satisfied: xmltodict>=0.12.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from motmetrics->-r requirements.txt (line 18)) (0.13.0)
# Requirement already satisfied: click>=8.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from flask>=1.1.1->visualdl>=2.2.0->-r requirements.txt (line 3)) (8.0.4)
# Requirement already satisfied: Werkzeug>=2.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from flask>=1.1.1->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from flask>=1.1.1->visualdl>=2.2.0->-r requirements.txt (line 3)) (6.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/conda/lib/python3.8/site-packages (from flask>=1.1.1->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from flask>=1.1.1->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: Babel<3.0.0,>=2.11.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from Flask-Babel>=3.0.0->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.11.0)
# Requirement already satisfied: pytz<2023.0,>=2022.7 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from Flask-Babel>=3.0.0->visualdl>=2.2.0->-r requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.0.7)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.0.8)
# Requirement already satisfied: fonttools>=4.22.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from matplotlib->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from onnx>=1.6.0->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.4.0)
# Requirement already satisfied: pycryptodome>=3.8.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from bce-python-sdk->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.17)
# Requirement already satisfied: future>=0.6.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from bce-python-sdk->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.18.3)
# Requirement already satisfied: uvicorn in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.20.0)
# Requirement already satisfied: websockets>=10.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (10.4)
# Requirement already satisfied: markupsafe in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: pydantic in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.10.4)
# Requirement already satisfied: python-multipart in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.0.5)
# Requirement already satisfied: altair>=4.2.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.2.2)
# Requirement already satisfied: aiohttp in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.8.3)
# Requirement already satisfied: pydub in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.25.1)
# Requirement already satisfied: markdown-it-py[linkify,plugins]>=2.0.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: httpx in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.23.3)
# Requirement already satisfied: fastapi in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.89.1)
# Requirement already satisfied: ffmpy in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: orjson in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.8.5)
# Requirement already satisfied: aiofiles in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.8/site-packages (from gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (2022.3.0)
# Requirement already satisfied: dill>=0.3.6 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from multiprocess->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.3.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from requests->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests->visualdl>=2.2.0->-r requirements.txt (line 3)) (2021.10.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from requests->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from scikit-learn->sklearn==0.0->-r requirements.txt (line 19)) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from scikit-learn->sklearn==0.0->-r requirements.txt (line 19)) (1.2.0)
# Requirement already satisfied: python-rapidjson>=0.9.1 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.9)
# Requirement already satisfied: grpcio>=1.41.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.51.1)
# Requirement already satisfied: geventhttpclient<=2.0.2,>=1.4.4 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: sympy in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from x2paddle->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.11.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from aiohttp->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.0.2)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.8/site-packages (from altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.4.0)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.8/site-packages (from altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.4)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.8/site-packages (from altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.11.2)
# Requirement already satisfied: gevent>=0.13 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from geventhttpclient<=2.0.2,>=1.4.4->tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (22.10.2)
# Requirement already satisfied: brotli in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from geventhttpclient<=2.0.2,>=1.4.4->tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: zipp>=0.5 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from markdown-it-py[linkify,plugins]>=2.0.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: mdit-py-plugins in /opt/conda/lib/python3.8/site-packages (from markdown-it-py[linkify,plugins]>=2.0.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: linkify-it-py~=1.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from markdown-it-py[linkify,plugins]>=2.0.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.0.3)
# Collecting starlette==0.22.0
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 291.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from starlette==0.22.0->fastapi->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (3.6.2)
# Requirement already satisfied: sniffio in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from httpx->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from httpx->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from httpx->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: mpmath>=0.19 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from sympy->x2paddle->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: h11>=0.8 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from uvicorn->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: zope.interface in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gevent>=0.13->geventhttpclient<=2.0.2,>=1.4.4->tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (5.5.2)
# Requirement already satisfied: greenlet>=2.0.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gevent>=0.13->geventhttpclient<=2.0.2,>=1.4.4->tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: zope.event in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from gevent>=0.13->geventhttpclient<=2.0.2,>=1.4.4->tritonclient[all]->visualdl>=2.2.0->-r requirements.txt (line 3)) (4.6)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (5.10.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: uc-micro-py in /home/5qx9nf8a/.local/lib/python3.8/site-packages (from linkify-it-py~=1.0->markdown-it-py[linkify,plugins]>=2.0.0->gradio->visualdl>=2.2.0->-r requirements.txt (line 3)) (1.0.1)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1304 sha256=71edf1263c2e2215ab867ecaf648007d8e3690563cfb9655b0c8e23c5046a6e8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4xwaje4c/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# WARNING: Ignoring invalid distribution -rotobuf (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# Installing collected packages: opencv-python, starlette, sklearn
#   Attempting uninstall: starlette
#     WARNING: Ignoring invalid distribution -rotobuf (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
#     WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
#     Found existing installation: starlette 0.20.4
#     Uninstalling starlette-0.20.4:
#       Successfully uninstalled starlette-0.20.4
# WARNING: Ignoring invalid distribution -rotobuf (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fiftyone 0.18.0 requires starlette==0.20.4, but you have starlette 0.22.0 which is incompatible.
# Successfully installed opencv-python-4.5.5.64 sklearn-0.0 starlette-0.22.0
# WARNING: Ignoring invalid distribution -rotobuf (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (/home/5qx9nf8a/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle-gpu (/home/5qx9nf8a/.local/lib/python3.8/site-packages)

# %%
# 1.训练（单卡/多卡），加 --eval 表示边训边评估，加 --amp 表示混合精度训练
# !cd PaddleYOLO && CUDA_VISIBLE_DEVICES=0 python tools/train.py -c PaddleDetection/PaddleYOLO/configs/custom/yolov8_m_500e_coco.yml --eval --amp
# Out:
# Traceback (most recent call last):
#   File "tools/train.py", line 32, in <module>
#     from ppdet.core.workspace import load_config, merge_config
#   File "/teams/hack_team_09/workspace/PaddleDetection/PaddleYOLO/ppdet/__init__.py", line 15, in <module>
#     from . import (core, data, engine, modeling, model_zoo, optimizer, metrics,
#   File "/teams/hack_team_09/workspace/PaddleDetection/PaddleYOLO/ppdet/data/__init__.py", line 16, in <module>
#     from . import transform
#   File "/teams/hack_team_09/workspace/PaddleDetection/PaddleYOLO/ppdet/data/transform/__init__.py", line 15, in <module>
#     from . import operators
#   File "/teams/hack_team_09/workspace/PaddleDetection/PaddleYOLO/ppdet/data/transform/operators.py", line 37, in <module>
#     import cv2
#   File "/home/5qx9nf8a/.local/lib/python3.8/site-packages/cv2/__init__.py", line 8, in <module>
#     from .cv2 import *
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory

# %% [markdown]
# ## Export: To TRT and ONNX

# %%
#!CUDA_VISIBLE_DEVICES=0 python tools/export_model.py -c configs/mot/bytetrack/detector/ppyoloe_crn_l_36e_640x640_mot17half.yml -o weights=https://paddledet.bj.bcebos.com/models/mot/ppyoloe_crn_l_36e_640x640_mot17half.pdparams
# %cd PaddleDetection
# !CUDA_VISIBLE_DEVICES=0 python tools/export_model.py -c /home/5qx9nf8a/team_workspace/PaddleDetection/configs/mot/bytetrack/detector/ppyoloe_plus_l_bytetrack.yml -o weights=/home/5qx9nf8a/team_workspace/PaddleDetection//tracking/model_final.pdparams
# Out:
# [Errno 2] No such file or directory: 'PaddleDetection'
# /teams/hack_team_09/workspace/PaddleDetection
# NOTE! Installing ujson may make loading annotations faster.
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.0.attn.fc.bias is unmatched with the shape [96] in model backbone.stages.0.attn.fc.bias. And the weight backbone.stages.0.attn.fc.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 1, 1] in pretrained weight backbone.stages.0.attn.fc.weight is unmatched with the shape [96, 96, 1, 1] in model backbone.stages.0.attn.fc.weight. And the weight backbone.stages.0.attn.fc.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv1.bn._mean is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv1.bn._mean. And the weight backbone.stages.0.blocks.0.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv1.bn._variance is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv1.bn._variance. And the weight backbone.stages.0.blocks.0.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv1.bn.bias is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv1.bn.bias. And the weight backbone.stages.0.blocks.0.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv1.bn.weight is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv1.bn.weight. And the weight backbone.stages.0.blocks.0.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36, 36, 3, 3] in pretrained weight backbone.stages.0.blocks.0.conv1.conv.weight is unmatched with the shape [48, 48, 3, 3] in model backbone.stages.0.blocks.0.conv1.conv.weight. And the weight backbone.stages.0.blocks.0.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv2.conv1.bn._mean is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv2.conv1.bn._mean. And the weight backbone.stages.0.blocks.0.conv2.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv2.conv1.bn._variance is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv2.conv1.bn._variance. And the weight backbone.stages.0.blocks.0.conv2.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv2.conv1.bn.bias is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv2.conv1.bn.bias. And the weight backbone.stages.0.blocks.0.conv2.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv2.conv1.bn.weight is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv2.conv1.bn.weight. And the weight backbone.stages.0.blocks.0.conv2.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36, 36, 3, 3] in pretrained weight backbone.stages.0.blocks.0.conv2.conv1.conv.weight is unmatched with the shape [48, 48, 3, 3] in model backbone.stages.0.blocks.0.conv2.conv1.conv.weight. And the weight backbone.stages.0.blocks.0.conv2.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv2.conv2.bn._mean is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv2.conv2.bn._mean. And the weight backbone.stages.0.blocks.0.conv2.conv2.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv2.conv2.bn._variance is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv2.conv2.bn._variance. And the weight backbone.stages.0.blocks.0.conv2.conv2.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv2.conv2.bn.bias is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv2.conv2.bn.bias. And the weight backbone.stages.0.blocks.0.conv2.conv2.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.0.conv2.conv2.bn.weight is unmatched with the shape [48] in model backbone.stages.0.blocks.0.conv2.conv2.bn.weight. And the weight backbone.stages.0.blocks.0.conv2.conv2.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36, 36, 1, 1] in pretrained weight backbone.stages.0.blocks.0.conv2.conv2.conv.weight is unmatched with the shape [48, 48, 1, 1] in model backbone.stages.0.blocks.0.conv2.conv2.conv.weight. And the weight backbone.stages.0.blocks.0.conv2.conv2.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv1.bn._mean is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv1.bn._mean. And the weight backbone.stages.0.blocks.1.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv1.bn._variance is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv1.bn._variance. And the weight backbone.stages.0.blocks.1.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv1.bn.bias is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv1.bn.bias. And the weight backbone.stages.0.blocks.1.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv1.bn.weight is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv1.bn.weight. And the weight backbone.stages.0.blocks.1.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36, 36, 3, 3] in pretrained weight backbone.stages.0.blocks.1.conv1.conv.weight is unmatched with the shape [48, 48, 3, 3] in model backbone.stages.0.blocks.1.conv1.conv.weight. And the weight backbone.stages.0.blocks.1.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv2.conv1.bn._mean is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv2.conv1.bn._mean. And the weight backbone.stages.0.blocks.1.conv2.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv2.conv1.bn._variance is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv2.conv1.bn._variance. And the weight backbone.stages.0.blocks.1.conv2.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv2.conv1.bn.bias is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv2.conv1.bn.bias. And the weight backbone.stages.0.blocks.1.conv2.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv2.conv1.bn.weight is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv2.conv1.bn.weight. And the weight backbone.stages.0.blocks.1.conv2.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36, 36, 3, 3] in pretrained weight backbone.stages.0.blocks.1.conv2.conv1.conv.weight is unmatched with the shape [48, 48, 3, 3] in model backbone.stages.0.blocks.1.conv2.conv1.conv.weight. And the weight backbone.stages.0.blocks.1.conv2.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv2.conv2.bn._mean is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv2.conv2.bn._mean. And the weight backbone.stages.0.blocks.1.conv2.conv2.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv2.conv2.bn._variance is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv2.conv2.bn._variance. And the weight backbone.stages.0.blocks.1.conv2.conv2.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv2.conv2.bn.bias is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv2.conv2.bn.bias. And the weight backbone.stages.0.blocks.1.conv2.conv2.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.blocks.1.conv2.conv2.bn.weight is unmatched with the shape [48] in model backbone.stages.0.blocks.1.conv2.conv2.bn.weight. And the weight backbone.stages.0.blocks.1.conv2.conv2.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36, 36, 1, 1] in pretrained weight backbone.stages.0.blocks.1.conv2.conv2.conv.weight is unmatched with the shape [48, 48, 1, 1] in model backbone.stages.0.blocks.1.conv2.conv2.conv.weight. And the weight backbone.stages.0.blocks.1.conv2.conv2.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.conv1.bn._mean is unmatched with the shape [48] in model backbone.stages.0.conv1.bn._mean. And the weight backbone.stages.0.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.conv1.bn._variance is unmatched with the shape [48] in model backbone.stages.0.conv1.bn._variance. And the weight backbone.stages.0.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.conv1.bn.bias is unmatched with the shape [48] in model backbone.stages.0.conv1.bn.bias. And the weight backbone.stages.0.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.conv1.bn.weight is unmatched with the shape [48] in model backbone.stages.0.conv1.bn.weight. And the weight backbone.stages.0.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36, 72, 1, 1] in pretrained weight backbone.stages.0.conv1.conv.weight is unmatched with the shape [48, 96, 1, 1] in model backbone.stages.0.conv1.conv.weight. And the weight backbone.stages.0.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.conv2.bn._mean is unmatched with the shape [48] in model backbone.stages.0.conv2.bn._mean. And the weight backbone.stages.0.conv2.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.conv2.bn._variance is unmatched with the shape [48] in model backbone.stages.0.conv2.bn._variance. And the weight backbone.stages.0.conv2.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.conv2.bn.bias is unmatched with the shape [48] in model backbone.stages.0.conv2.bn.bias. And the weight backbone.stages.0.conv2.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36] in pretrained weight backbone.stages.0.conv2.bn.weight is unmatched with the shape [48] in model backbone.stages.0.conv2.bn.weight. And the weight backbone.stages.0.conv2.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [36, 72, 1, 1] in pretrained weight backbone.stages.0.conv2.conv.weight is unmatched with the shape [48, 96, 1, 1] in model backbone.stages.0.conv2.conv.weight. And the weight backbone.stages.0.conv2.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [96] in pretrained weight backbone.stages.0.conv3.bn._mean is unmatched with the shape [128] in model backbone.stages.0.conv3.bn._mean. And the weight backbone.stages.0.conv3.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [96] in pretrained weight backbone.stages.0.conv3.bn._variance is unmatched with the shape [128] in model backbone.stages.0.conv3.bn._variance. And the weight backbone.stages.0.conv3.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [96] in pretrained weight backbone.stages.0.conv3.bn.bias is unmatched with the shape [128] in model backbone.stages.0.conv3.bn.bias. And the weight backbone.stages.0.conv3.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [96] in pretrained weight backbone.stages.0.conv3.bn.weight is unmatched with the shape [128] in model backbone.stages.0.conv3.bn.weight. And the weight backbone.stages.0.conv3.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [96, 72, 1, 1] in pretrained weight backbone.stages.0.conv3.conv.weight is unmatched with the shape [128, 96, 1, 1] in model backbone.stages.0.conv3.conv.weight. And the weight backbone.stages.0.conv3.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.0.conv_down.bn._mean is unmatched with the shape [96] in model backbone.stages.0.conv_down.bn._mean. And the weight backbone.stages.0.conv_down.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.0.conv_down.bn._variance is unmatched with the shape [96] in model backbone.stages.0.conv_down.bn._variance. And the weight backbone.stages.0.conv_down.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.0.conv_down.bn.bias is unmatched with the shape [96] in model backbone.stages.0.conv_down.bn.bias. And the weight backbone.stages.0.conv_down.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.0.conv_down.bn.weight is unmatched with the shape [96] in model backbone.stages.0.conv_down.bn.weight. And the weight backbone.stages.0.conv_down.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 48, 3, 3] in pretrained weight backbone.stages.0.conv_down.conv.weight is unmatched with the shape [96, 64, 3, 3] in model backbone.stages.0.conv_down.conv.weight. And the weight backbone.stages.0.conv_down.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.1.attn.fc.bias is unmatched with the shape [192] in model backbone.stages.1.attn.fc.bias. And the weight backbone.stages.1.attn.fc.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 1, 1] in pretrained weight backbone.stages.1.attn.fc.weight is unmatched with the shape [192, 192, 1, 1] in model backbone.stages.1.attn.fc.weight. And the weight backbone.stages.1.attn.fc.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv1.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv1.bn._mean. And the weight backbone.stages.1.blocks.0.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv1.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv1.bn._variance. And the weight backbone.stages.1.blocks.0.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv1.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv1.bn.bias. And the weight backbone.stages.1.blocks.0.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv1.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv1.bn.weight. And the weight backbone.stages.1.blocks.0.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 3, 3] in pretrained weight backbone.stages.1.blocks.0.conv1.conv.weight is unmatched with the shape [96, 96, 3, 3] in model backbone.stages.1.blocks.0.conv1.conv.weight. And the weight backbone.stages.1.blocks.0.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv2.conv1.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv2.conv1.bn._mean. And the weight backbone.stages.1.blocks.0.conv2.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv2.conv1.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv2.conv1.bn._variance. And the weight backbone.stages.1.blocks.0.conv2.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv2.conv1.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv2.conv1.bn.bias. And the weight backbone.stages.1.blocks.0.conv2.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv2.conv1.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv2.conv1.bn.weight. And the weight backbone.stages.1.blocks.0.conv2.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 3, 3] in pretrained weight backbone.stages.1.blocks.0.conv2.conv1.conv.weight is unmatched with the shape [96, 96, 3, 3] in model backbone.stages.1.blocks.0.conv2.conv1.conv.weight. And the weight backbone.stages.1.blocks.0.conv2.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv2.conv2.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv2.conv2.bn._mean. And the weight backbone.stages.1.blocks.0.conv2.conv2.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv2.conv2.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv2.conv2.bn._variance. And the weight backbone.stages.1.blocks.0.conv2.conv2.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv2.conv2.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv2.conv2.bn.bias. And the weight backbone.stages.1.blocks.0.conv2.conv2.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.0.conv2.conv2.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.0.conv2.conv2.bn.weight. And the weight backbone.stages.1.blocks.0.conv2.conv2.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 1, 1] in pretrained weight backbone.stages.1.blocks.0.conv2.conv2.conv.weight is unmatched with the shape [96, 96, 1, 1] in model backbone.stages.1.blocks.0.conv2.conv2.conv.weight. And the weight backbone.stages.1.blocks.0.conv2.conv2.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv1.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv1.bn._mean. And the weight backbone.stages.1.blocks.1.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv1.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv1.bn._variance. And the weight backbone.stages.1.blocks.1.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv1.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv1.bn.bias. And the weight backbone.stages.1.blocks.1.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv1.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv1.bn.weight. And the weight backbone.stages.1.blocks.1.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 3, 3] in pretrained weight backbone.stages.1.blocks.1.conv1.conv.weight is unmatched with the shape [96, 96, 3, 3] in model backbone.stages.1.blocks.1.conv1.conv.weight. And the weight backbone.stages.1.blocks.1.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv2.conv1.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv2.conv1.bn._mean. And the weight backbone.stages.1.blocks.1.conv2.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv2.conv1.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv2.conv1.bn._variance. And the weight backbone.stages.1.blocks.1.conv2.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv2.conv1.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv2.conv1.bn.bias. And the weight backbone.stages.1.blocks.1.conv2.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv2.conv1.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv2.conv1.bn.weight. And the weight backbone.stages.1.blocks.1.conv2.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 3, 3] in pretrained weight backbone.stages.1.blocks.1.conv2.conv1.conv.weight is unmatched with the shape [96, 96, 3, 3] in model backbone.stages.1.blocks.1.conv2.conv1.conv.weight. And the weight backbone.stages.1.blocks.1.conv2.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv2.conv2.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv2.conv2.bn._mean. And the weight backbone.stages.1.blocks.1.conv2.conv2.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv2.conv2.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv2.conv2.bn._variance. And the weight backbone.stages.1.blocks.1.conv2.conv2.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv2.conv2.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv2.conv2.bn.bias. And the weight backbone.stages.1.blocks.1.conv2.conv2.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.1.conv2.conv2.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.1.conv2.conv2.bn.weight. And the weight backbone.stages.1.blocks.1.conv2.conv2.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 1, 1] in pretrained weight backbone.stages.1.blocks.1.conv2.conv2.conv.weight is unmatched with the shape [96, 96, 1, 1] in model backbone.stages.1.blocks.1.conv2.conv2.conv.weight. And the weight backbone.stages.1.blocks.1.conv2.conv2.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv1.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv1.bn._mean. And the weight backbone.stages.1.blocks.2.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv1.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv1.bn._variance. And the weight backbone.stages.1.blocks.2.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv1.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv1.bn.bias. And the weight backbone.stages.1.blocks.2.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv1.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv1.bn.weight. And the weight backbone.stages.1.blocks.2.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 3, 3] in pretrained weight backbone.stages.1.blocks.2.conv1.conv.weight is unmatched with the shape [96, 96, 3, 3] in model backbone.stages.1.blocks.2.conv1.conv.weight. And the weight backbone.stages.1.blocks.2.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv2.conv1.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv2.conv1.bn._mean. And the weight backbone.stages.1.blocks.2.conv2.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv2.conv1.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv2.conv1.bn._variance. And the weight backbone.stages.1.blocks.2.conv2.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv2.conv1.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv2.conv1.bn.bias. And the weight backbone.stages.1.blocks.2.conv2.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv2.conv1.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv2.conv1.bn.weight. And the weight backbone.stages.1.blocks.2.conv2.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 3, 3] in pretrained weight backbone.stages.1.blocks.2.conv2.conv1.conv.weight is unmatched with the shape [96, 96, 3, 3] in model backbone.stages.1.blocks.2.conv2.conv1.conv.weight. And the weight backbone.stages.1.blocks.2.conv2.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv2.conv2.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv2.conv2.bn._mean. And the weight backbone.stages.1.blocks.2.conv2.conv2.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv2.conv2.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv2.conv2.bn._variance. And the weight backbone.stages.1.blocks.2.conv2.conv2.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv2.conv2.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv2.conv2.bn.bias. And the weight backbone.stages.1.blocks.2.conv2.conv2.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.2.conv2.conv2.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.2.conv2.conv2.bn.weight. And the weight backbone.stages.1.blocks.2.conv2.conv2.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 1, 1] in pretrained weight backbone.stages.1.blocks.2.conv2.conv2.conv.weight is unmatched with the shape [96, 96, 1, 1] in model backbone.stages.1.blocks.2.conv2.conv2.conv.weight. And the weight backbone.stages.1.blocks.2.conv2.conv2.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv1.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv1.bn._mean. And the weight backbone.stages.1.blocks.3.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv1.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv1.bn._variance. And the weight backbone.stages.1.blocks.3.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv1.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv1.bn.bias. And the weight backbone.stages.1.blocks.3.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv1.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv1.bn.weight. And the weight backbone.stages.1.blocks.3.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 3, 3] in pretrained weight backbone.stages.1.blocks.3.conv1.conv.weight is unmatched with the shape [96, 96, 3, 3] in model backbone.stages.1.blocks.3.conv1.conv.weight. And the weight backbone.stages.1.blocks.3.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv2.conv1.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv2.conv1.bn._mean. And the weight backbone.stages.1.blocks.3.conv2.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv2.conv1.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv2.conv1.bn._variance. And the weight backbone.stages.1.blocks.3.conv2.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv2.conv1.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv2.conv1.bn.bias. And the weight backbone.stages.1.blocks.3.conv2.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv2.conv1.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv2.conv1.bn.weight. And the weight backbone.stages.1.blocks.3.conv2.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 3, 3] in pretrained weight backbone.stages.1.blocks.3.conv2.conv1.conv.weight is unmatched with the shape [96, 96, 3, 3] in model backbone.stages.1.blocks.3.conv2.conv1.conv.weight. And the weight backbone.stages.1.blocks.3.conv2.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv2.conv2.bn._mean is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv2.conv2.bn._mean. And the weight backbone.stages.1.blocks.3.conv2.conv2.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv2.conv2.bn._variance is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv2.conv2.bn._variance. And the weight backbone.stages.1.blocks.3.conv2.conv2.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv2.conv2.bn.bias is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv2.conv2.bn.bias. And the weight backbone.stages.1.blocks.3.conv2.conv2.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.blocks.3.conv2.conv2.bn.weight is unmatched with the shape [96] in model backbone.stages.1.blocks.3.conv2.conv2.bn.weight. And the weight backbone.stages.1.blocks.3.conv2.conv2.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 72, 1, 1] in pretrained weight backbone.stages.1.blocks.3.conv2.conv2.conv.weight is unmatched with the shape [96, 96, 1, 1] in model backbone.stages.1.blocks.3.conv2.conv2.conv.weight. And the weight backbone.stages.1.blocks.3.conv2.conv2.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.conv1.bn._mean is unmatched with the shape [96] in model backbone.stages.1.conv1.bn._mean. And the weight backbone.stages.1.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.conv1.bn._variance is unmatched with the shape [96] in model backbone.stages.1.conv1.bn._variance. And the weight backbone.stages.1.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.conv1.bn.bias is unmatched with the shape [96] in model backbone.stages.1.conv1.bn.bias. And the weight backbone.stages.1.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.conv1.bn.weight is unmatched with the shape [96] in model backbone.stages.1.conv1.bn.weight. And the weight backbone.stages.1.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 144, 1, 1] in pretrained weight backbone.stages.1.conv1.conv.weight is unmatched with the shape [96, 192, 1, 1] in model backbone.stages.1.conv1.conv.weight. And the weight backbone.stages.1.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.conv2.bn._mean is unmatched with the shape [96] in model backbone.stages.1.conv2.bn._mean. And the weight backbone.stages.1.conv2.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.conv2.bn._variance is unmatched with the shape [96] in model backbone.stages.1.conv2.bn._variance. And the weight backbone.stages.1.conv2.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.conv2.bn.bias is unmatched with the shape [96] in model backbone.stages.1.conv2.bn.bias. And the weight backbone.stages.1.conv2.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72] in pretrained weight backbone.stages.1.conv2.bn.weight is unmatched with the shape [96] in model backbone.stages.1.conv2.bn.weight. And the weight backbone.stages.1.conv2.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [72, 144, 1, 1] in pretrained weight backbone.stages.1.conv2.conv.weight is unmatched with the shape [96, 192, 1, 1] in model backbone.stages.1.conv2.conv.weight. And the weight backbone.stages.1.conv2.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [192] in pretrained weight backbone.stages.1.conv3.bn._mean is unmatched with the shape [256] in model backbone.stages.1.conv3.bn._mean. And the weight backbone.stages.1.conv3.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [192] in pretrained weight backbone.stages.1.conv3.bn._variance is unmatched with the shape [256] in model backbone.stages.1.conv3.bn._variance. And the weight backbone.stages.1.conv3.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [192] in pretrained weight backbone.stages.1.conv3.bn.bias is unmatched with the shape [256] in model backbone.stages.1.conv3.bn.bias. And the weight backbone.stages.1.conv3.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [192] in pretrained weight backbone.stages.1.conv3.bn.weight is unmatched with the shape [256] in model backbone.stages.1.conv3.bn.weight. And the weight backbone.stages.1.conv3.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [192, 144, 1, 1] in pretrained weight backbone.stages.1.conv3.conv.weight is unmatched with the shape [256, 192, 1, 1] in model backbone.stages.1.conv3.conv.weight. And the weight backbone.stages.1.conv3.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.1.conv_down.bn._mean is unmatched with the shape [192] in model backbone.stages.1.conv_down.bn._mean. And the weight backbone.stages.1.conv_down.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.1.conv_down.bn._variance is unmatched with the shape [192] in model backbone.stages.1.conv_down.bn._variance. And the weight backbone.stages.1.conv_down.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.1.conv_down.bn.bias is unmatched with the shape [192] in model backbone.stages.1.conv_down.bn.bias. And the weight backbone.stages.1.conv_down.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.1.conv_down.bn.weight is unmatched with the shape [192] in model backbone.stages.1.conv_down.bn.weight. And the weight backbone.stages.1.conv_down.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 96, 3, 3] in pretrained weight backbone.stages.1.conv_down.conv.weight is unmatched with the shape [192, 128, 3, 3] in model backbone.stages.1.conv_down.conv.weight. And the weight backbone.stages.1.conv_down.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight backbone.stages.2.attn.fc.bias is unmatched with the shape [384] in model backbone.stages.2.attn.fc.bias. And the weight backbone.stages.2.attn.fc.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288, 288, 1, 1] in pretrained weight backbone.stages.2.attn.fc.weight is unmatched with the shape [384, 384, 1, 1] in model backbone.stages.2.attn.fc.weight. And the weight backbone.stages.2.attn.fc.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv1.bn._mean is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv1.bn._mean. And the weight backbone.stages.2.blocks.0.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv1.bn._variance is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv1.bn._variance. And the weight backbone.stages.2.blocks.0.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv1.bn.bias is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv1.bn.bias. And the weight backbone.stages.2.blocks.0.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv1.bn.weight is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv1.bn.weight. And the weight backbone.stages.2.blocks.0.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 3, 3] in pretrained weight backbone.stages.2.blocks.0.conv1.conv.weight is unmatched with the shape [192, 192, 3, 3] in model backbone.stages.2.blocks.0.conv1.conv.weight. And the weight backbone.stages.2.blocks.0.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv2.conv1.bn._mean is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv2.conv1.bn._mean. And the weight backbone.stages.2.blocks.0.conv2.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv2.conv1.bn._variance is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv2.conv1.bn._variance. And the weight backbone.stages.2.blocks.0.conv2.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv2.conv1.bn.bias is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv2.conv1.bn.bias. And the weight backbone.stages.2.blocks.0.conv2.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv2.conv1.bn.weight is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv2.conv1.bn.weight. And the weight backbone.stages.2.blocks.0.conv2.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 3, 3] in pretrained weight backbone.stages.2.blocks.0.conv2.conv1.conv.weight is unmatched with the shape [192, 192, 3, 3] in model backbone.stages.2.blocks.0.conv2.conv1.conv.weight. And the weight backbone.stages.2.blocks.0.conv2.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv2.conv2.bn._mean is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv2.conv2.bn._mean. And the weight backbone.stages.2.blocks.0.conv2.conv2.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv2.conv2.bn._variance is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv2.conv2.bn._variance. And the weight backbone.stages.2.blocks.0.conv2.conv2.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv2.conv2.bn.bias is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv2.conv2.bn.bias. And the weight backbone.stages.2.blocks.0.conv2.conv2.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.0.conv2.conv2.bn.weight is unmatched with the shape [192] in model backbone.stages.2.blocks.0.conv2.conv2.bn.weight. And the weight backbone.stages.2.blocks.0.conv2.conv2.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 1, 1] in pretrained weight backbone.stages.2.blocks.0.conv2.conv2.conv.weight is unmatched with the shape [192, 192, 1, 1] in model backbone.stages.2.blocks.0.conv2.conv2.conv.weight. And the weight backbone.stages.2.blocks.0.conv2.conv2.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.1.conv1.bn._mean is unmatched with the shape [192] in model backbone.stages.2.blocks.1.conv1.bn._mean. And the weight backbone.stages.2.blocks.1.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.1.conv1.bn._variance is unmatched with the shape [192] in model backbone.stages.2.blocks.1.conv1.bn._variance. And the weight backbone.stages.2.blocks.1.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.1.conv1.bn.bias is unmatched with the shape [192] in model backbone.stages.2.blocks.1.conv1.bn.bias. And the weight backbone.stages.2.blocks.1.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.1.conv1.bn.weight is unmatched with the shape [192] in model backbone.stages.2.blocks.1.conv1.bn.weight. And the weight backbone.stages.2.blocks.1.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 3, 3] in pretrained weight backbone.stages.2.blocks.1.conv1.conv.weight is unmatched with the shape [192, 192, 3, 3] in model backbone.stages.2.blocks.1.conv1.conv.weight. And the weight backbone.stages.2.blocks.1.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.1.conv2.conv1.bn._mean is unmatched with the shape [192] in model backbone.stages.2.blocks.1.conv2.conv1.bn._mean. And the weight backbone.stages.2.blocks.1.conv2.conv1.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.1.conv2.conv1.bn._variance is unmatched with the shape [192] in model backbone.stages.2.blocks.1.conv2.conv1.bn._variance. And the weight backbone.stages.2.blocks.1.conv2.conv1.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.1.conv2.conv1.bn.bias is unmatched with the shape [192] in model backbone.stages.2.blocks.1.conv2.conv1.bn.bias. And the weight backbone.stages.2.blocks.1.conv2.conv1.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.1.conv2.conv1.bn.weight is unmatched with the shape [192] in model backbone.stages.2.blocks.1.conv2.conv1.bn.weight. And the weight backbone.stages.2.blocks.1.conv2.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 3, 3] in pretrained weight backbone.stages.2.blocks.1.conv2.conv1.conv.weight is unmatched with the shape [192, 192, 3, 3] in model backbone.stages.2.blocks.1.conv2.conv1.conv.weight. And the weight backbone.stages.2.blocks.1.conv2.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight backbone.stages.2.blocks.1.conv2.conv2.bn._mean is unmatched with the shape [192] in model backbone.stages.2.blocks.1.conv2.conv2.bn._mean. And the weight backbone.stages.2.blocks.1.conv2.conv2.bn._mean will not be loaded
# ...
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight neck.pan_stages.1.0.convs.1.conv2.conv1.bn.weight is unmatched with the shape [192] in model neck.pan_stages.1.0.convs.1.conv2.conv1.bn.weight. And the weight neck.pan_stages.1.0.convs.1.conv2.conv1.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 3, 3] in pretrained weight neck.pan_stages.1.0.convs.1.conv2.conv1.conv.weight is unmatched with the shape [192, 192, 3, 3] in model neck.pan_stages.1.0.convs.1.conv2.conv1.conv.weight. And the weight neck.pan_stages.1.0.convs.1.conv2.conv1.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight neck.pan_stages.1.0.convs.1.conv2.conv2.bn._mean is unmatched with the shape [192] in model neck.pan_stages.1.0.convs.1.conv2.conv2.bn._mean. And the weight neck.pan_stages.1.0.convs.1.conv2.conv2.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight neck.pan_stages.1.0.convs.1.conv2.conv2.bn._variance is unmatched with the shape [192] in model neck.pan_stages.1.0.convs.1.conv2.conv2.bn._variance. And the weight neck.pan_stages.1.0.convs.1.conv2.conv2.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight neck.pan_stages.1.0.convs.1.conv2.conv2.bn.bias is unmatched with the shape [192] in model neck.pan_stages.1.0.convs.1.conv2.conv2.bn.bias. And the weight neck.pan_stages.1.0.convs.1.conv2.conv2.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight neck.pan_stages.1.0.convs.1.conv2.conv2.bn.weight is unmatched with the shape [192] in model neck.pan_stages.1.0.convs.1.conv2.conv2.bn.weight. And the weight neck.pan_stages.1.0.convs.1.conv2.conv2.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 1, 1] in pretrained weight neck.pan_stages.1.0.convs.1.conv2.conv2.conv.weight is unmatched with the shape [192, 192, 1, 1] in model neck.pan_stages.1.0.convs.1.conv2.conv2.conv.weight. And the weight neck.pan_stages.1.0.convs.1.conv2.conv2.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [6, 576, 3, 3] in pretrained weight yolo_head.pred_cls.0.weight is unmatched with the shape [6, 768, 3, 3] in model yolo_head.pred_cls.0.weight. And the weight yolo_head.pred_cls.0.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [6, 288, 3, 3] in pretrained weight yolo_head.pred_cls.1.weight is unmatched with the shape [6, 384, 3, 3] in model yolo_head.pred_cls.1.weight. And the weight yolo_head.pred_cls.1.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [6, 144, 3, 3] in pretrained weight yolo_head.pred_cls.2.weight is unmatched with the shape [6, 192, 3, 3] in model yolo_head.pred_cls.2.weight. And the weight yolo_head.pred_cls.2.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [68, 576, 3, 3] in pretrained weight yolo_head.pred_reg.0.weight is unmatched with the shape [68, 768, 3, 3] in model yolo_head.pred_reg.0.weight. And the weight yolo_head.pred_reg.0.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [68, 288, 3, 3] in pretrained weight yolo_head.pred_reg.1.weight is unmatched with the shape [68, 384, 3, 3] in model yolo_head.pred_reg.1.weight. And the weight yolo_head.pred_reg.1.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [68, 144, 3, 3] in pretrained weight yolo_head.pred_reg.2.weight is unmatched with the shape [68, 192, 3, 3] in model yolo_head.pred_reg.2.weight. And the weight yolo_head.pred_reg.2.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576] in pretrained weight yolo_head.stem_cls.0.conv.bn._mean is unmatched with the shape [768] in model yolo_head.stem_cls.0.conv.bn._mean. And the weight yolo_head.stem_cls.0.conv.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576] in pretrained weight yolo_head.stem_cls.0.conv.bn._variance is unmatched with the shape [768] in model yolo_head.stem_cls.0.conv.bn._variance. And the weight yolo_head.stem_cls.0.conv.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576] in pretrained weight yolo_head.stem_cls.0.conv.bn.bias is unmatched with the shape [768] in model yolo_head.stem_cls.0.conv.bn.bias. And the weight yolo_head.stem_cls.0.conv.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576] in pretrained weight yolo_head.stem_cls.0.conv.bn.weight is unmatched with the shape [768] in model yolo_head.stem_cls.0.conv.bn.weight. And the weight yolo_head.stem_cls.0.conv.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576, 576, 1, 1] in pretrained weight yolo_head.stem_cls.0.conv.conv.weight is unmatched with the shape [768, 768, 1, 1] in model yolo_head.stem_cls.0.conv.conv.weight. And the weight yolo_head.stem_cls.0.conv.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576] in pretrained weight yolo_head.stem_cls.0.fc.bias is unmatched with the shape [768] in model yolo_head.stem_cls.0.fc.bias. And the weight yolo_head.stem_cls.0.fc.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576, 576, 1, 1] in pretrained weight yolo_head.stem_cls.0.fc.weight is unmatched with the shape [768, 768, 1, 1] in model yolo_head.stem_cls.0.fc.weight. And the weight yolo_head.stem_cls.0.fc.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight yolo_head.stem_cls.1.conv.bn._mean is unmatched with the shape [384] in model yolo_head.stem_cls.1.conv.bn._mean. And the weight yolo_head.stem_cls.1.conv.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight yolo_head.stem_cls.1.conv.bn._variance is unmatched with the shape [384] in model yolo_head.stem_cls.1.conv.bn._variance. And the weight yolo_head.stem_cls.1.conv.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight yolo_head.stem_cls.1.conv.bn.bias is unmatched with the shape [384] in model yolo_head.stem_cls.1.conv.bn.bias. And the weight yolo_head.stem_cls.1.conv.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight yolo_head.stem_cls.1.conv.bn.weight is unmatched with the shape [384] in model yolo_head.stem_cls.1.conv.bn.weight. And the weight yolo_head.stem_cls.1.conv.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288, 288, 1, 1] in pretrained weight yolo_head.stem_cls.1.conv.conv.weight is unmatched with the shape [384, 384, 1, 1] in model yolo_head.stem_cls.1.conv.conv.weight. And the weight yolo_head.stem_cls.1.conv.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight yolo_head.stem_cls.1.fc.bias is unmatched with the shape [384] in model yolo_head.stem_cls.1.fc.bias. And the weight yolo_head.stem_cls.1.fc.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288, 288, 1, 1] in pretrained weight yolo_head.stem_cls.1.fc.weight is unmatched with the shape [384, 384, 1, 1] in model yolo_head.stem_cls.1.fc.weight. And the weight yolo_head.stem_cls.1.fc.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight yolo_head.stem_cls.2.conv.bn._mean is unmatched with the shape [192] in model yolo_head.stem_cls.2.conv.bn._mean. And the weight yolo_head.stem_cls.2.conv.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight yolo_head.stem_cls.2.conv.bn._variance is unmatched with the shape [192] in model yolo_head.stem_cls.2.conv.bn._variance. And the weight yolo_head.stem_cls.2.conv.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight yolo_head.stem_cls.2.conv.bn.bias is unmatched with the shape [192] in model yolo_head.stem_cls.2.conv.bn.bias. And the weight yolo_head.stem_cls.2.conv.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight yolo_head.stem_cls.2.conv.bn.weight is unmatched with the shape [192] in model yolo_head.stem_cls.2.conv.bn.weight. And the weight yolo_head.stem_cls.2.conv.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 1, 1] in pretrained weight yolo_head.stem_cls.2.conv.conv.weight is unmatched with the shape [192, 192, 1, 1] in model yolo_head.stem_cls.2.conv.conv.weight. And the weight yolo_head.stem_cls.2.conv.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight yolo_head.stem_cls.2.fc.bias is unmatched with the shape [192] in model yolo_head.stem_cls.2.fc.bias. And the weight yolo_head.stem_cls.2.fc.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 1, 1] in pretrained weight yolo_head.stem_cls.2.fc.weight is unmatched with the shape [192, 192, 1, 1] in model yolo_head.stem_cls.2.fc.weight. And the weight yolo_head.stem_cls.2.fc.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576] in pretrained weight yolo_head.stem_reg.0.conv.bn._mean is unmatched with the shape [768] in model yolo_head.stem_reg.0.conv.bn._mean. And the weight yolo_head.stem_reg.0.conv.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576] in pretrained weight yolo_head.stem_reg.0.conv.bn._variance is unmatched with the shape [768] in model yolo_head.stem_reg.0.conv.bn._variance. And the weight yolo_head.stem_reg.0.conv.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576] in pretrained weight yolo_head.stem_reg.0.conv.bn.bias is unmatched with the shape [768] in model yolo_head.stem_reg.0.conv.bn.bias. And the weight yolo_head.stem_reg.0.conv.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576] in pretrained weight yolo_head.stem_reg.0.conv.bn.weight is unmatched with the shape [768] in model yolo_head.stem_reg.0.conv.bn.weight. And the weight yolo_head.stem_reg.0.conv.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576, 576, 1, 1] in pretrained weight yolo_head.stem_reg.0.conv.conv.weight is unmatched with the shape [768, 768, 1, 1] in model yolo_head.stem_reg.0.conv.conv.weight. And the weight yolo_head.stem_reg.0.conv.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576] in pretrained weight yolo_head.stem_reg.0.fc.bias is unmatched with the shape [768] in model yolo_head.stem_reg.0.fc.bias. And the weight yolo_head.stem_reg.0.fc.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [576, 576, 1, 1] in pretrained weight yolo_head.stem_reg.0.fc.weight is unmatched with the shape [768, 768, 1, 1] in model yolo_head.stem_reg.0.fc.weight. And the weight yolo_head.stem_reg.0.fc.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight yolo_head.stem_reg.1.conv.bn._mean is unmatched with the shape [384] in model yolo_head.stem_reg.1.conv.bn._mean. And the weight yolo_head.stem_reg.1.conv.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight yolo_head.stem_reg.1.conv.bn._variance is unmatched with the shape [384] in model yolo_head.stem_reg.1.conv.bn._variance. And the weight yolo_head.stem_reg.1.conv.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight yolo_head.stem_reg.1.conv.bn.bias is unmatched with the shape [384] in model yolo_head.stem_reg.1.conv.bn.bias. And the weight yolo_head.stem_reg.1.conv.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight yolo_head.stem_reg.1.conv.bn.weight is unmatched with the shape [384] in model yolo_head.stem_reg.1.conv.bn.weight. And the weight yolo_head.stem_reg.1.conv.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288, 288, 1, 1] in pretrained weight yolo_head.stem_reg.1.conv.conv.weight is unmatched with the shape [384, 384, 1, 1] in model yolo_head.stem_reg.1.conv.conv.weight. And the weight yolo_head.stem_reg.1.conv.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288] in pretrained weight yolo_head.stem_reg.1.fc.bias is unmatched with the shape [384] in model yolo_head.stem_reg.1.fc.bias. And the weight yolo_head.stem_reg.1.fc.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [288, 288, 1, 1] in pretrained weight yolo_head.stem_reg.1.fc.weight is unmatched with the shape [384, 384, 1, 1] in model yolo_head.stem_reg.1.fc.weight. And the weight yolo_head.stem_reg.1.fc.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight yolo_head.stem_reg.2.conv.bn._mean is unmatched with the shape [192] in model yolo_head.stem_reg.2.conv.bn._mean. And the weight yolo_head.stem_reg.2.conv.bn._mean will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight yolo_head.stem_reg.2.conv.bn._variance is unmatched with the shape [192] in model yolo_head.stem_reg.2.conv.bn._variance. And the weight yolo_head.stem_reg.2.conv.bn._variance will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight yolo_head.stem_reg.2.conv.bn.bias is unmatched with the shape [192] in model yolo_head.stem_reg.2.conv.bn.bias. And the weight yolo_head.stem_reg.2.conv.bn.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight yolo_head.stem_reg.2.conv.bn.weight is unmatched with the shape [192] in model yolo_head.stem_reg.2.conv.bn.weight. And the weight yolo_head.stem_reg.2.conv.bn.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 1, 1] in pretrained weight yolo_head.stem_reg.2.conv.conv.weight is unmatched with the shape [192, 192, 1, 1] in model yolo_head.stem_reg.2.conv.conv.weight. And the weight yolo_head.stem_reg.2.conv.conv.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144] in pretrained weight yolo_head.stem_reg.2.fc.bias is unmatched with the shape [192] in model yolo_head.stem_reg.2.fc.bias. And the weight yolo_head.stem_reg.2.fc.bias will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: The shape [144, 144, 1, 1] in pretrained weight yolo_head.stem_reg.2.fc.weight is unmatched with the shape [192, 192, 1, 1] in model yolo_head.stem_reg.2.fc.weight. And the weight yolo_head.stem_reg.2.fc.weight will not be loaded
# [02/09 05:14:34] ppdet.utils.checkpoint INFO: Finish loading model weights: /home/5qx9nf8a/team_workspace/PaddleDetection//tracking/model_final.pdparams
# [02/09 05:14:35] ppdet.data.source.category WARNING: anno_file 'dataset/coco/annotations/instances_val2017.json' is None or not set or not exist, please recheck TrainDataset/EvalDataset/TestDataset.anno_path, otherwise the default categories will be used by metric_type.
# [02/09 05:14:35] ppdet.data.source.category WARNING: metric_type: COCO, load default categories of COCO.
# [02/09 05:14:35] ppdet.engine INFO: Export inference config file to output_inference/ppyoloe_plus_l_bytetrack/infer_cfg.yml
# [02/09 05:14:41] ppdet.engine INFO: Export model and saved in output_inference/ppyoloe_plus_l_bytetrack

# %%
model.info()
# Out:
# YOLOv8m summary: 218 layers, 25843234 parameters, 0 gradients, 78.7 GFLOPs

# %%
model.val()
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.8.13 torch-1.13.1+cu117 CUDA:0 (NVIDIA A100-SXM4-80GB, 81112MiB)
# val: Scanning /teams/hack_team_09/workspace/data/trans_data/val/labels.cache... 1000 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1000/1000 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 63/63 [00:35<00:00,  1.78it/s]
#                    all       1000      39332      0.944      0.896      0.963      0.931
#          klt_box_empty       1000      16453      0.999      0.782      0.926      0.883
#           klt_box_full       1000      19518      0.995      0.762      0.942      0.882
#                 rack_1       1000        715      0.678      0.933      0.947      0.902
#                 rack_2       1000        581          1      0.977      0.987      0.963
#                 rack_3       1000       1063          1      0.971      0.991      0.987
#                 rack_4       1000       1002      0.992      0.951      0.984      0.969
# Speed: 0.3ms pre-process, 3.2ms inference, 0.0ms loss, 1.3ms post-process per image

# %%
from tracking.tracking_counter import create_submission_dict, write_submission

#submission_dict = create_submission_dict(scanned_racks=scanner.rack_tracks, mAP=96.3, fps=19.47)99.71
submission_dict = create_submission_dict(scanned_racks=saved_racks, mAP=96.3, fps=0) 

write_submission(submission_dict=submission_dict, submission_path="temp/AcademicWeapons.json")

# %%
video = "data/Hackathon_Stage2/Evaluation_set/video/eval_video_1.mp4"
img = "data/Hackathon_Stage2/Evaluation_set/dataset/images/109.jpg"
engine = "runs/detect/train2/weights/best.engine"
data = "data/trans_data/val/images"
import cv2
im = cv2.imread(img)[None]
print(im.shape)
from ultralytics.yolo.v8.detect.predict import DetectionPredictor
predictor = DetectionPredictor() #CustomPredictor()#
predictor.setup_model(model=engine)
predictor.imgsz = (3, 960, 960)
predictor.args.mode = "predict"
predictor.args.imgsz = 960
predictor.args.save = False
predictor.args.cache = True
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.8.13 torch-1.13.1+cu117 CUDA:0 (NVIDIA A100-SXM4-80GB, 81112MiB)
# Loading runs/detect/train2/weights/best.engine for TensorRT inference...
# (1, 720, 1280, 3)
# [02/02/2023-00:12:52] [TRT] [I] The logger passed into createInferRuntime differs from one already provided for an existing builder, runtime, or refitter. Uses of the global logger, returned by nvinfer1::getLogger(), will return the existing value.
#
# [02/02/2023-00:12:52] [TRT] [I] Loaded engine size: 51 MiB
# [02/02/2023-00:12:52] [TRT] [I] [MemUsageChange] Init cuDNN: CPU +0, GPU +35, now: CPU 2647, GPU 3498 (MiB)
# [02/02/2023-00:12:52] [TRT] [W] TensorRT was linked against cuDNN 8.6.0 but loaded cuDNN 8.5.0
# [02/02/2023-00:12:52] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +50, now: CPU 3, GPU 1624 (MiB)
# [02/02/2023-00:12:52] [TRT] [I] [MemUsageChange] Init cuDNN: CPU +0, GPU +32, now: CPU 2595, GPU 3498 (MiB)
# [02/02/2023-00:12:52] [TRT] [W] TensorRT was linked against cuDNN 8.6.0 but loaded cuDNN 8.5.0
# [02/02/2023-00:12:52] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +175, now: CPU 3, GPU 1799 (MiB)
# [02/02/2023-00:12:52] [TRT] [W] CUDA lazy loading is not enabled. Enabling it can significantly reduce device memory usage. See `CUDA_MODULE_LOADING` in https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#env-vars

# %%
from time import time

with VideoSink(TARGET_VIDEO_PATH, 1, video_info) as sink:
    detect_time, track_up_time, track_matcher, box_anno, scanner_up, scanner_anno, writer = 0,0,0,0,0,0,0
    
    for idx, frame in tqdm(enumerate(generator), total=video_info.total_frames):
        
        start = time()
        results = predictor(source=frame)
        end = time()
        detect_time += end - start
        
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        if detections.xyxy.shape[0] != 0:
            # tracking detections
            start = time()
            tracks = byte_tracker.update(
                output_results=detections2boxes(detections=detections),
                img_info=frame.shape,
                img_size=frame.shape
            )
            end = time()
            track_up_time += end - start
            
            start = time()
            tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
            end = time()
            track_matcher += end - start
            
            detections.tracker_id = np.array(tracker_id)

            # filtering out detections without trackers
            mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
            detections.filter(mask=mask, inplace=True)
            detection_list.append(detections)
            
            # format custom labels
            labels = [
                f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
                for _, confidence, class_id, tracker_id
                in detections
            ]
            
            # annotatoe detection boxes
            start = time()
            #frame = box_annotator.annotate(
            #    frame=frame, detections=detections, labels=labels
            #)
            end = time()
            box_anno += end - start
            
            # update the scanner
            start = time()
            scanner.update(detections=detections)
            end = time()
            scanner_up += end - start
            # draw the scanner
            start = time()
            #scanner_annotator.annotate(frame=frame, rack_scanner=scanner)
            end = time()
            scanner_anno += end - start
            # add the annotated frame to video
        start = time()
        sink.write_frame(frame)
        end = time()
        writer += end - start
print(round(detect_time, 3)*  1000)
print(round(track_up_time, 3)* 1000)
print(round(track_matcher, 3)* 1000)
print(round(box_anno, 3)* 1000)
print(round(scanner_up, 3)* 1000)
print(round(scanner_anno, 3)* 1000)
print(round(writer, 3)* 1000)
# Out:
# 3253it [01:57, 29.32it/s]
# This is the last frame
# 3361it [02:00, 27.91it/s]
# Elapsed time: 120.44 seconds for 3252 frames
# Average FPS: 27.00 frames per second
# 40580.0
# 26731.0
# 3037.0
# 1.0
# 5884.0
# 1.0
# 37239.0
